# %% [markdown]
# # Rename and prepare for fine tuning
#
# This script is to prepare the generated/reconstrcuted data from VideoVAE to the Fall classifier model fine-tuning

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
version_number = 'v10.02'
save_dir = f'/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_{version_number}/videos/reconstructions'
origin_df_csv = '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/full_standardized.csv'
df_origin = pd.read_csv(origin_df_csv, index_col = 0)

# %% [markdown]
# # Renaming the Files

# %%
df_camera1 = df_origin[df_origin['full_path'].str.contains('Camera1')]
df_grouped = df_camera1.groupby('Timestamp').first().reset_index()
fall_grouped = df_grouped[df_grouped['Tag'] < 6]
fall_grouped = fall_grouped.reset_index(drop=True)
fall_grouped.index = fall_grouped.index + 1
fall_grouped
# Out:
#                       Timestamp                  frame_name  Subject  \
# 1    2018-07-04 12:04:20.238369  2018-07-04T12_04_20.259248        1
# 2    2018-07-04 12:04:20.738369  2018-07-04T12_04_20.763596        1
# 3    2018-07-04 12:04:21.238369  2018-07-04T12_04_21.242877        1
# 4    2018-07-04 12:04:21.738369  2018-07-04T12_04_21.769786        1
# 5    2018-07-04 12:04:22.238369  2018-07-04T12_04_22.275163        1
# ..                          ...                         ...      ...
# 628  2018-07-12 11:59:55.648720  2018-07-12T11_59_55.653412       17
# 629  2018-07-12 12:00:10.275836  2018-07-12T12_00_10.323636       17
# 630  2018-07-12 12:00:10.775836  2018-07-12T12_00_10.777348       17
# 631  2018-07-12 12:00:11.275836  2018-07-12T12_00_11.296234       17
# 632  2018-07-12 12:00:11.775836  2018-07-12T12_00_11.812613       17
#
#      Activity  Trial                                          full_path  \
# 1           1      1  /content/drive/MyDrive/Fall-Detection/UP-Fall-...
# 2           1      1  /content/drive/MyDrive/Fall-Detection/UP-Fall-...
# 3           1      1  /content/drive/MyDrive/Fall-Detection/UP-Fall-...
# 4           1      1  /content/drive/MyDrive/Fall-Detection/UP-Fall-...
# 5           1      1  /content/drive/MyDrive/Fall-Detection/UP-Fall-...
# ..        ...    ...                                                ...
# 628         5      2  /content/drive/MyDrive/Fall-Detection/UP-Fall-...
# 629         5      3  /content/drive/MyDrive/Fall-Detection/UP-Fall-...
# 630         5      3  /content/drive/MyDrive/Fall-Detection/UP-Fall-...
# 631         5      3  /content/drive/MyDrive/Fall-Detection/UP-Fall-...
# 632         5      3  /content/drive/MyDrive/Fall-Detection/UP-Fall-...
#
#         frame_name_standardized  Tag  Fall
# 1    2018-07-04 12:04:20.238369    1     1
# 2    2018-07-04 12:04:20.738369    1     1
# 3    2018-07-04 12:04:21.238369    1     1
# 4    2018-07-04 12:04:21.738369    1     1
# 5    2018-07-04 12:04:22.238369    1     1
# ..                          ...  ...   ...
# 628  2018-07-12 11:59:55.648720    5     1
# 629  2018-07-12 12:00:10.275836    5     1
# 630  2018-07-12 12:00:10.775836    5     1
# 631  2018-07-12 12:00:11.275836    5     1
# 632  2018-07-12 12:00:11.775836    5     1
#
# [632 rows x 9 columns]

# %% [markdown]
# ## Check if all the required video chuncks are generated

# %%
num_directories2 = 0
for item in os.listdir(save_dir):
  item_path = os.path.join(save_dir, item)
  if os.path.isdir(item_path):
    num_directories2 += 1

print(f"Number of directories in {save_dir}: {num_directories2}")
# Out:
# Number of directories in /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions: 632

# %%
import os
import pandas as pd

rename_counts = {}

for i, row in enumerate(fall_grouped.itertuples(), start=1):
    full_path = row.full_path

    # Extract the folder name from the full_path
    # This grabs the parent directory name ("Subject1Activity1Trial1Camera1")
    base_folder = os.path.basename(os.path.dirname(full_path))

    # Check if this folder name has been used before
    if base_folder in rename_counts:
        rename_counts[base_folder] += 1
        new_folder_name = f"{base_folder}_{rename_counts[base_folder]}"
    else:
        rename_counts[base_folder] = 1
        new_folder_name = base_folder

    # Construct old and new directory paths
    old_dir = os.path.join(save_dir, f"reconstructed_video_{i}")
    new_dir = os.path.join(save_dir, new_folder_name)

    # Rename the directory
    os.rename(old_dir, new_dir)
    print(f"Renamed '{old_dir}' to '{new_dir}'")
# Out:
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_1' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity1Trial1Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_2' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity1Trial1Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_3' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity1Trial1Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_4' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity1Trial1Camera1_4'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_5' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity1Trial1Camera1_5'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_6' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity1Trial1Camera1_6'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_7' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity1Trial3Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_8' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity1Trial3Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_9' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity1Trial3Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_10' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity1Trial3Camera1_4'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_11' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity2Trial1Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_12' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity2Trial1Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_13' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity2Trial1Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_14' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity2Trial1Camera1_4'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_15' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity2Trial1Camera1_5'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_16' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity3Trial1Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_17' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity3Trial1Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_18' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity3Trial1Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_19' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity3Trial1Camera1_4'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_20' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity3Trial1Camera1_5'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_21' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity3Trial1Camera1_6'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_22' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity3Trial1Camera1_7'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_23' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity3Trial2Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_24' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity3Trial2Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_25' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity3Trial2Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_26' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity3Trial2Camera1_4'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_27' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity3Trial2Camera1_5'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_28' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity3Trial2Camera1_6'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_29' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity3Trial3Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_30' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity3Trial3Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_31' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity3Trial3Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_32' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity3Trial3Camera1_4'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_33' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity3Trial3Camera1_5'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_34' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity3Trial3Camera1_6'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_35' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity4Trial1Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_36' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity4Trial1Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_37' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity4Trial1Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_38' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity4Trial1Camera1_4'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_39' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity5Trial1Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_40' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity5Trial1Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_41' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity5Trial1Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_42' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity5Trial1Camera1_4'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_43' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity5Trial1Camera1_5'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_44' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity5Trial1Camera1_6'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_45' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity5Trial2Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_46' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity5Trial2Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_47' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity5Trial2Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_48' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity5Trial2Camera1_4'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_49' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity5Trial2Camera1_5'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_50' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity5Trial3Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_51' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity5Trial3Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_52' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity5Trial3Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_53' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity5Trial3Camera1_4'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_54' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity5Trial3Camera1_5'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_55' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject1Activity5Trial3Camera1_6'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_56' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity1Trial1Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_57' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity1Trial1Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_58' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity1Trial1Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_59' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity1Trial1Camera1_4'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_60' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity1Trial2Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_61' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity1Trial2Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_62' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity1Trial2Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_63' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity1Trial2Camera1_4'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_64' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity1Trial2Camera1_5'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_65' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity1Trial2Camera1_6'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_66' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity1Trial3Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_67' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity1Trial3Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_68' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity1Trial3Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_69' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity1Trial3Camera1_4'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_70' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity2Trial1Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_71' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity2Trial1Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_72' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity2Trial1Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_73' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity2Trial1Camera1_4'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_74' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity2Trial1Camera1_5'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_75' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity2Trial1Camera1_6'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_76' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity2Trial1Camera1_7'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_77' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity3Trial2Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_78' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity3Trial2Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_79' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity3Trial2Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_80' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity3Trial2Camera1_4'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_81' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity3Trial2Camera1_5'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_82' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity3Trial2Camera1_6'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_83' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity3Trial3Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_84' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity3Trial3Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_85' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity3Trial3Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_86' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity3Trial3Camera1_4'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_87' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity3Trial3Camera1_5'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_88' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity4Trial1Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_89' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity4Trial1Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_90' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity4Trial1Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_91' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity4Trial1Camera1_4'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_92' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity4Trial2Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_93' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity4Trial2Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_94' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity4Trial2Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_95' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity4Trial2Camera1_4'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_96' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity4Trial3Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_97' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity4Trial3Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_98' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity4Trial3Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_99' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity5Trial1Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_100' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity5Trial1Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_101' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity5Trial1Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_102' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity5Trial1Camera1_4'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_103' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity5Trial2Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_104' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity5Trial2Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_105' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity5Trial2Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_106' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject3Activity5Trial2Camera1_4'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_107' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject5Activity1Trial1Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_108' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject5Activity1Trial1Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_109' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject5Activity1Trial1Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_110' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject5Activity1Trial2Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_111' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject5Activity1Trial2Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_112' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject5Activity1Trial2Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_113' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject5Activity3Trial1Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_114' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject5Activity3Trial1Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_115' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject5Activity3Trial1Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_116' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject5Activity4Trial1Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_117' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject5Activity4Trial1Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_118' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject5Activity4Trial1Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_119' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject5Activity4Trial3Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_120' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject5Activity4Trial3Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_121' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject5Activity4Trial3Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_122' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject5Activity5Trial1Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_123' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject5Activity5Trial1Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_124' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject5Activity5Trial1Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_125' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject6Activity1Trial1Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_126' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject6Activity1Trial1Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_127' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject6Activity1Trial1Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_128' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject6Activity1Trial3Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_129' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject6Activity1Trial3Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_130' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject6Activity1Trial3Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_131' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject6Activity2Trial2Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_132' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject6Activity2Trial2Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_133' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject6Activity2Trial2Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_134' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject6Activity2Trial3Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_135' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject6Activity2Trial3Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_136' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject6Activity2Trial3Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_137' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject6Activity3Trial1Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_138' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject6Activity3Trial1Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_139' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject6Activity3Trial1Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_140' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject6Activity3Trial1Camera1_4'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_141' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject6Activity3Trial2Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_142' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject6Activity3Trial2Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_143' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject6Activity4Trial1Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_144' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject6Activity4Trial3Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_145' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject6Activity5Trial2Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_146' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject6Activity5Trial2Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_147' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject6Activity5Trial2Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_148' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject7Activity1Trial1Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_149' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject7Activity1Trial1Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_150' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject7Activity1Trial1Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_151' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject7Activity1Trial3Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_152' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject7Activity1Trial3Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_153' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject7Activity1Trial3Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_154' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject7Activity2Trial1Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_155' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject7Activity2Trial3Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_156' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject7Activity3Trial1Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_157' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject7Activity3Trial1Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_158' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject7Activity3Trial1Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_159' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject7Activity3Trial2Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_160' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject7Activity3Trial2Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_161' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject7Activity3Trial2Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_162' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject7Activity3Trial2Camera1_4'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_163' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject7Activity3Trial3Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_164' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject7Activity3Trial3Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_165' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject7Activity3Trial3Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_166' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject7Activity4Trial1Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_167' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject7Activity4Trial1Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_168' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject7Activity4Trial1Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_169' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject7Activity4Trial2Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_170' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject7Activity4Trial2Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_171' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject7Activity4Trial2Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_172' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject7Activity4Trial2Camera1_4'
# ...
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_576' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject16Activity5Trial2Camera1_4'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_577' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject16Activity5Trial2Camera1_5'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_578' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity1Trial1Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_579' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity1Trial1Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_580' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity1Trial1Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_581' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity1Trial1Camera1_4'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_582' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity1Trial2Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_583' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity1Trial2Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_584' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity1Trial2Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_585' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity1Trial2Camera1_4'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_586' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity1Trial3Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_587' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity1Trial3Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_588' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity1Trial3Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_589' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity1Trial3Camera1_4'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_590' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity1Trial3Camera1_5'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_591' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity1Trial3Camera1_6'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_592' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity2Trial1Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_593' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity2Trial1Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_594' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity2Trial1Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_595' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity2Trial1Camera1_4'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_596' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity2Trial1Camera1_5'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_597' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity2Trial3Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_598' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity2Trial3Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_599' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity2Trial3Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_600' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity2Trial3Camera1_4'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_601' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity2Trial3Camera1_5'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_602' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity3Trial1Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_603' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity3Trial1Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_604' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity3Trial1Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_605' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity3Trial1Camera1_4'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_606' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity3Trial2Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_607' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity3Trial2Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_608' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity3Trial2Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_609' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity3Trial2Camera1_4'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_610' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity3Trial2Camera1_5'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_611' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity4Trial1Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_612' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity4Trial1Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_613' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity4Trial1Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_614' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity4Trial1Camera1_4'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_615' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity4Trial3Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_616' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity4Trial3Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_617' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity4Trial3Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_618' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity4Trial3Camera1_4'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_619' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity5Trial1Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_620' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity5Trial1Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_621' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity5Trial1Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_622' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity5Trial1Camera1_4'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_623' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity5Trial1Camera1_5'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_624' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity5Trial2Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_625' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity5Trial2Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_626' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity5Trial2Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_627' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity5Trial2Camera1_4'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_628' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity5Trial2Camera1_5'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_629' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity5Trial3Camera1'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_630' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity5Trial3Camera1_2'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_631' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity5Trial3Camera1_3'
# Renamed '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/reconstructed_video_632' to '/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/reconstructions/Subject17Activity5Trial3Camera1_4'

# %% [markdown]
# # Preproceccing the Frames to NPY

# %%
import os
import pandas as pd

# Extract folder names from the full_path
folder_names = fall_grouped['full_path'].apply(lambda path: os.path.basename(os.path.dirname(path)))

# Count how many times each folder appears
folder_counts = folder_names.value_counts()

# Compute basic stats
average = folder_counts.mean()
minimum = folder_counts.min()
maximum = folder_counts.max()

# Count how many folders have exactly _1, _2, _3... directories
count_distribution = folder_counts.value_counts().sort_index()

# Print stats
print("Folder counts for each case:")
print(folder_counts)

print("\nDistribution of number of folders per case:")
print(count_distribution)

print(f"\nAverage folders per case: {average:.2f}")
print(f"Minimum folders per case: {minimum}")
print(f"Maximum folders per case: {maximum}")
# Out:
# Folder counts for each case:
# full_path
# Subject2Activity3Trial2Camera1     8
# Subject1Activity3Trial1Camera1     7
# Subject8Activity5Trial2Camera1     7
# Subject2Activity5Trial1Camera1     7
# Subject3Activity2Trial1Camera1     7
#                                   ..
# Subject12Activity2Trial2Camera1    1
# Subject12Activity2Trial1Camera1    1
# Subject10Activity2Trial1Camera1    1
# Subject15Activity1Trial3Camera1    1
# Subject15Activity1Trial1Camera1    1
# Name: count, Length: 170, dtype: int64
#
# Distribution of number of folders per case:
# count
# 1    11
# 2    22
# 3    47
# 4    42
# 5    26
# 6    17
# 7     4
# 8     1
# Name: count, dtype: int64
#
# Average folders per case: 3.72
# Minimum folders per case: 1
# Maximum folders per case: 8

# %% [markdown]
# ## These functions are mainly from KTP project, to match the data preparation for their Model

# %%
import os
import re
import cv2
import logging
import numpy as np
from tqdm import tqdm
from pathlib import Path
from typing import List, Tuple, Optional
from concurrent.futures import ThreadPoolExecutor

logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")

def extract_activity_name(folder_name: str):
    """
    Extracts the base activity name from a folder name.
    Example: "fall_2" -> "fall"
    """
    m = re.match(r"^(.*?)(?:_(\d+))?$", folder_name)
    if m:
        return m.group(1)
    return folder_name

def get_folder_order(folder_name: str):
    """
    Extracts an order number from a folder name.
    If no order is found, returns 1.
    """
    m = re.match(r"^(.*?)(?:_(\d+))?$", folder_name)
    if m:
        return int(m.group(2)) if m.group(2) else 1
    return 1

class FrameDifferenceComputer:
    @staticmethod
    def compute_frame_difference(prev_frame: np.ndarray, current_frame: np.ndarray):
        """
        Computes the absolute difference between two normalised frames,
        followed by a Gaussian blur.
        """
        prev_norm = cv2.normalize(prev_frame, None, 0, 255, cv2.NORM_MINMAX, cv2.CV_8U)
        curr_norm = cv2.normalize(current_frame, None, 0, 255, cv2.NORM_MINMAX, cv2.CV_8U)
        diff = cv2.absdiff(prev_norm, curr_norm)
        diff_blurred = cv2.GaussianBlur(diff, (5, 5), 0)
        return diff_blurred

class OpticalFlowComputer:
    def __init__(self, pyr_scale: float = 0.5, levels: int = 3, winsize: int = 15,
                 iterations: int = 3, poly_n: int = 5, poly_sigma: float = 1.2,
                 flags: int = 0, resize_dim: Tuple[int, int] = (38, 51)) -> None:
        self.pyr_scale = pyr_scale
        self.levels = levels
        self.winsize = winsize
        self.iterations = iterations
        self.poly_n = poly_n
        self.poly_sigma = poly_sigma
        self.flags = flags
        self.resize_dim = resize_dim

    def compute_optical_flow(self, prev_frame: np.ndarray, current_frame: np.ndarray) -> Tuple[np.ndarray, np.ndarray]:
        """
        Computes optical flow between two frames using Farneback's method and
        resizes the flow components.
        """
        flow = cv2.calcOpticalFlowFarneback(prev_frame, current_frame, None,
                                            self.pyr_scale, self.levels, self.winsize,
                                            self.iterations, self.poly_n, self.poly_sigma,
                                            self.flags)
        u_component = flow[..., 0]
        v_component = flow[..., 1]
        resized_u = cv2.resize(u_component, self.resize_dim)
        resized_v = cv2.resize(v_component, self.resize_dim)
        return resized_u, resized_v

class ActivityFrameLoader:
    def __init__(self, folder_list: List[Path]) -> None:
        self.folder_list = folder_list

    def load_frames(self) -> List[Tuple[str, np.ndarray]]:
        """
        Loads PNG frames from the list of folders in sorted order concurrently.
        Returns a list of tuples (filename, image) with an overall progress bar.
        """
        def load_image(file_path: Path) -> Optional[Tuple[str, np.ndarray]]:
            img = cv2.imread(str(file_path), cv2.IMREAD_GRAYSCALE)
            if img is None:
                logging.warning(f"Failed to load image {file_path}")
                return None
            return (file_path.name, img)

        # Gather all file paths from all folders (ordered by folder order and then file name)
        all_file_paths: List[Path] = []
        for folder in sorted(self.folder_list, key=lambda x: get_folder_order(x.name)):
            sorted_files = sorted(folder.glob("*.png"))
            all_file_paths.extend(sorted_files)

        total_files = len(all_file_paths)
        logging.info(f"Found {total_files} image files to load.")

        # Use ThreadPoolExecutor to load images concurrently with a progress bar.
        with ThreadPoolExecutor() as executor:
            results = list(tqdm(executor.map(load_image, all_file_paths), total=total_files, desc="Loading images"))

        # Filter out None results and return the list of frames.
        frames = [res for res in results if res is not None]
        return frames

class NumpyWriter:
    def __init__(self, output_folder: Path) -> None:
        self.output_folder = output_folder
        self.output_folder.mkdir(parents=True, exist_ok=True)

    def write_array(self, array: np.ndarray, name: str, activity_folder: Path) -> None:
        """
        Writes the numpy array to a file in the specified activity folder.
        """
        file_path = activity_folder / f"{name}.npy"
        np.save(str(file_path), array)
        logging.info(f"Saved processed file: {file_path}")

class ActivityOpticalFlowProcessor:
    def __init__(self, input_base_dir: Path, output_folder: Path, fps: int = 18) -> None:
        self.input_base_dir = input_base_dir
        self.output_folder = output_folder
        self.fps = fps
        self.window_size = fps
        self.optical_flow_computer = OpticalFlowComputer()
        self.numpy_writer = NumpyWriter(output_folder)

    def process_activity(self, activity_name: str, folder_paths: List[Path]) -> None:
        logging.info(f"Processing activity: {activity_name} with {len(folder_paths)} folders")
        # Sort folders by their numerical order.
        folder_paths_sorted = sorted(folder_paths, key=lambda x: get_folder_order(x.name))
        frame_loader = ActivityFrameLoader(folder_paths_sorted)
        frames = frame_loader.load_frames()

        if len(frames) < self.window_size:
            logging.warning(f"Not enough frames for activity '{activity_name}'. Skipping.")
            return

        # Create a dedicated output directory for this activity.
        activity_output_dir = self.output_folder / activity_name
        activity_output_dir.mkdir(parents=True, exist_ok=True)

        window_index = 0
        i = 0
        # Process frames in non-overlapping windows.
        while i <= len(frames) - self.window_size:
            window_frames = frames[i:i+self.window_size]

            # Compute frame differences.
            frame_differences = []
            for j in range(len(window_frames) - 1):
                try:
                    diff = FrameDifferenceComputer.compute_frame_difference(window_frames[j][1],
                                                                            window_frames[j+1][1])
                    frame_differences.append(diff)
                except cv2.error as e:
                    logging.error(f"Error computing frame difference in activity '{activity_name}' at index {i+j}: {e}")
                    continue

            if len(frame_differences) < 2:
                i += self.window_size
                continue

            # Compute optical flows between consecutive frame differences.
            optical_flows_u = []
            optical_flows_v = []
            for k in range(len(frame_differences) - 1):
                try:
                    u, v = self.optical_flow_computer.compute_optical_flow(frame_differences[k],
                                                                           frame_differences[k+1])
                    optical_flows_u.append(u)
                    optical_flows_v.append(v)
                except cv2.error as e:
                    logging.error(f"Error computing optical flow in activity '{activity_name}' at window index {i+k}: {e}")
                    continue

            if optical_flows_u and optical_flows_v:
                optical_flows_u_array = np.stack(optical_flows_u, axis=0)
                optical_flows_v_array = np.stack(optical_flows_v, axis=0)
                # Combine u and v components into one array.
                combined_optical_flow = np.stack([optical_flows_u_array, optical_flows_v_array], axis=-1)
                file_name = f"window_{window_index:03d}"
                # Write the file concurrently.
                with ThreadPoolExecutor() as executor:
                    executor.submit(self.numpy_writer.write_array, combined_optical_flow, file_name, activity_output_dir)
                window_index += 1

            i += self.window_size

    def run(self) -> None:
        """
        Groups subdirectories by activity name and processes each activity that has at least 2 folders.
        """
        activity_groups: dict[str, List[Path]] = {}
        for item in self.input_base_dir.iterdir():
            if item.is_dir():
                base_activity = extract_activity_name(item.name)
                activity_groups.setdefault(base_activity, []).append(item)

        activities = list(activity_groups.items())
        total_activities = len(activities)
        logging.info(f"Processing {total_activities} activities.")

        # Wrap the loop with tqdm for an overall progress bar.
        for activity, folders in tqdm(activities, desc="Processing activities", total=total_activities):
            if len(folders) >= 2:
                self.process_activity(activity, folders)
            else:
                logging.info(f"Skipping activity '{activity}' as it has less than 2 directories.")

if __name__ == "__main__":
    # Define input and output directories using pathlib.Path.
    input_base_dir = Path(f"/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_{version_number}/videos/reconstructions")
    output_folder = Path(f"/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_{version_number}/videos/processed-npy-files")

    processor = ActivityOpticalFlowProcessor(input_base_dir, output_folder, fps=9)
    processor.run()
# Out:
# Processing activities:   0%|          | 0/170 [00:00<?, ?it/s]
# Loading images:   0%|          | 0/54 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/54 [00:00<00:23,  2.27it/s]
# Loading images:  11%|█         | 6/54 [00:00<00:03, 13.84it/s]
# Loading images:  17%|█▋        | 9/54 [00:00<00:02, 17.04it/s]
# Loading images:  30%|██▉       | 16/54 [00:00<00:01, 29.90it/s]
# Loading images:  39%|███▉      | 21/54 [00:00<00:01, 27.48it/s]
# Loading images:  46%|████▋     | 25/54 [00:01<00:01, 28.05it/s]
# Loading images:  54%|█████▎    | 29/54 [00:01<00:00, 28.48it/s]
# Loading images:  65%|██████▍   | 35/54 [00:01<00:00, 30.44it/s]
# Loading images:  72%|███████▏  | 39/54 [00:01<00:00, 30.31it/s]
# Loading images:  81%|████████▏ | 44/54 [00:01<00:00, 31.77it/s]
# Loading images: 100%|██████████| 54/54 [00:02<00:00, 26.25it/s]
# Processing activities:   1%|          | 1/170 [00:03<08:47,  3.12s/it]
# Loading images:   0%|          | 0/36 [00:00<?, ?it/s]
# Loading images:   3%|▎         | 1/36 [00:00<00:07,  4.48it/s]
# Loading images:   6%|▌         | 2/36 [00:00<00:06,  4.92it/s]
# Loading images:  11%|█         | 4/36 [00:00<00:03,  8.17it/s]
# Loading images:  42%|████▏     | 15/36 [00:00<00:00, 33.42it/s]
# Loading images:  56%|█████▌    | 20/36 [00:00<00:00, 29.86it/s]
# Loading images:  69%|██████▉   | 25/36 [00:01<00:00, 32.00it/s]
# Loading images: 100%|██████████| 36/36 [00:01<00:00, 26.18it/s]
# Processing activities:   1%|          | 2/170 [00:05<07:36,  2.72s/it]
# Loading images:   0%|          | 0/45 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/45 [00:00<00:18,  2.38it/s]
# Loading images:   4%|▍         | 2/45 [00:00<00:12,  3.31it/s]
# Loading images:  18%|█▊        | 8/45 [00:00<00:02, 12.42it/s]
# Loading images:  38%|███▊      | 17/45 [00:01<00:01, 24.77it/s]
# Loading images:  47%|████▋     | 21/45 [00:01<00:01, 16.75it/s]
# Loading images:  53%|█████▎    | 24/45 [00:01<00:01, 17.62it/s]
# Loading images: 100%|██████████| 45/45 [00:01<00:00, 24.77it/s]
# Processing activities:   2%|▏         | 3/170 [00:08<08:00,  2.88s/it]
# Loading images:   0%|          | 0/63 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/63 [00:00<00:29,  2.10it/s]
# Loading images:   3%|▎         | 2/63 [00:00<00:21,  2.81it/s]
# Loading images:  11%|█         | 7/63 [00:01<00:08,  6.72it/s]
# Loading images:  43%|████▎     | 27/63 [00:01<00:01, 30.31it/s]
# Loading images: 100%|██████████| 63/63 [00:02<00:00, 21.97it/s]
# Processing activities:   2%|▏         | 4/170 [00:13<10:04,  3.64s/it]
# Loading images:   0%|          | 0/54 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/54 [00:00<00:29,  1.77it/s]
# Loading images:  26%|██▌       | 14/54 [00:00<00:01, 24.39it/s]
# Loading images:  35%|███▌      | 19/54 [00:00<00:01, 25.62it/s]
# Loading images:  44%|████▍     | 24/54 [00:01<00:01, 26.47it/s]
# Loading images:  52%|█████▏    | 28/54 [00:01<00:00, 27.97it/s]
# Loading images:  61%|██████    | 33/54 [00:01<00:00, 29.27it/s]
# Loading images:  69%|██████▊   | 37/54 [00:01<00:00, 23.42it/s]
# Loading images: 100%|██████████| 54/54 [00:01<00:00, 29.63it/s]
# Processing activities:   3%|▎         | 5/170 [00:16<09:15,  3.37s/it]
# Loading images:   0%|          | 0/54 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/54 [00:00<00:16,  3.26it/s]
# Loading images:   4%|▎         | 2/54 [00:00<00:12,  4.07it/s]
# Loading images:  26%|██▌       | 14/54 [00:00<00:01, 25.51it/s]
# Loading images:  31%|███▏      | 17/54 [00:00<00:01, 25.39it/s]
# Loading images:  46%|████▋     | 25/54 [00:00<00:00, 34.79it/s]
# Loading images:  54%|█████▎    | 29/54 [00:01<00:00, 34.45it/s]
# Loading images:  61%|██████    | 33/54 [00:01<00:00, 31.17it/s]
# Loading images:  76%|███████▌  | 41/54 [00:01<00:00, 32.27it/s]
# Loading images:  85%|████████▌ | 46/54 [00:01<00:00, 28.94it/s]
# Loading images: 100%|██████████| 54/54 [00:01<00:00, 27.39it/s]
# Processing activities:   4%|▎         | 6/170 [00:18<08:07,  2.98s/it]
# Loading images:   0%|          | 0/36 [00:00<?, ?it/s]
# Loading images:   3%|▎         | 1/36 [00:00<00:10,  3.36it/s]
# Loading images:   8%|▊         | 3/36 [00:00<00:07,  4.22it/s]
# Loading images:  42%|████▏     | 15/36 [00:00<00:00, 25.32it/s]
# Loading images:  67%|██████▋   | 24/36 [00:01<00:00, 33.48it/s]
# Loading images: 100%|██████████| 36/36 [00:01<00:00, 25.32it/s]
# Processing activities:   4%|▍         | 7/170 [00:20<06:50,  2.52s/it]
# Loading images:   0%|          | 0/54 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/54 [00:00<00:21,  2.50it/s]
# Loading images:   7%|▋         | 4/54 [00:00<00:09,  5.19it/s]
# Loading images: 100%|██████████| 54/54 [00:02<00:00, 22.42it/s]
# Processing activities:   5%|▍         | 8/170 [00:22<06:55,  2.57s/it]
# Loading images:   0%|          | 0/45 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/45 [00:00<00:16,  2.67it/s]
# Loading images:  11%|█         | 5/45 [00:00<00:03, 11.77it/s]
# Loading images:  31%|███       | 14/45 [00:00<00:01, 30.94it/s]
# Loading images:  42%|████▏     | 19/45 [00:00<00:00, 27.77it/s]
# Loading images:  53%|█████▎    | 24/45 [00:01<00:00, 26.95it/s]
# Loading images: 100%|██████████| 45/45 [00:02<00:00, 18.56it/s]
# Processing activities:   5%|▌         | 9/170 [00:25<06:57,  2.59s/it]
# Loading images:   0%|          | 0/54 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/54 [00:00<00:10,  5.01it/s]
# Loading images:   4%|▎         | 2/54 [00:00<00:09,  5.28it/s]
# Loading images:  13%|█▎        | 7/54 [00:00<00:02, 17.14it/s]
# Loading images:  26%|██▌       | 14/54 [00:00<00:02, 17.90it/s]
# Loading images:  33%|███▎      | 18/54 [00:01<00:01, 19.33it/s]
# Loading images:  57%|█████▋    | 31/54 [00:01<00:00, 28.98it/s]
# Loading images:  63%|██████▎   | 34/54 [00:01<00:01, 17.21it/s]
# Loading images: 100%|██████████| 54/54 [00:02<00:00, 25.15it/s]
# Processing activities:   6%|▌         | 10/170 [00:27<06:44,  2.53s/it]
# Loading images:   0%|          | 0/36 [00:00<?, ?it/s]
# Loading images:   3%|▎         | 1/36 [00:00<00:14,  2.40it/s]
# Loading images:  11%|█         | 4/36 [00:00<00:03,  9.01it/s]
# Loading images:  19%|█▉        | 7/36 [00:00<00:03,  8.58it/s]
# Loading images: 100%|██████████| 36/36 [00:01<00:00, 25.11it/s]
# Processing activities:   6%|▋         | 11/170 [00:29<05:56,  2.24s/it]
# Loading images:   0%|          | 0/54 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/54 [00:00<00:20,  2.62it/s]
# Loading images:  17%|█▋        | 9/54 [00:00<00:02, 22.48it/s]
# Loading images:  26%|██▌       | 14/54 [00:00<00:01, 22.41it/s]
# Loading images:  35%|███▌      | 19/54 [00:00<00:01, 24.65it/s]
# Loading images:  48%|████▊     | 26/54 [00:01<00:00, 28.70it/s]
# Loading images:  56%|█████▌    | 30/54 [00:01<00:00, 25.82it/s]
# Loading images:  67%|██████▋   | 36/54 [00:01<00:00, 22.64it/s]
# Loading images: 100%|██████████| 54/54 [00:01<00:00, 29.47it/s]
# Processing activities:   7%|▋         | 12/170 [00:31<05:45,  2.19s/it]
# Loading images:   0%|          | 0/36 [00:00<?, ?it/s]
# Loading images:   3%|▎         | 1/36 [00:00<00:12,  2.78it/s]
# Loading images:  33%|███▎      | 12/36 [00:00<00:00, 33.05it/s]
# Loading images:  53%|█████▎    | 19/36 [00:00<00:00, 19.70it/s]
# Loading images:  69%|██████▉   | 25/36 [00:01<00:00, 25.99it/s]
# Loading images: 100%|██████████| 36/36 [00:01<00:00, 24.98it/s]
# Processing activities:   8%|▊         | 13/170 [00:33<05:16,  2.01s/it]
# Loading images:   0%|          | 0/63 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/63 [00:00<00:29,  2.13it/s]
# Loading images:   5%|▍         | 3/63 [00:01<00:21,  2.82it/s]
# Loading images:  51%|█████     | 32/63 [00:01<00:00, 38.68it/s]
# Loading images:  68%|██████▊   | 43/63 [00:01<00:00, 35.96it/s]
# Loading images:  81%|████████  | 51/63 [00:01<00:00, 33.75it/s]
# Loading images: 100%|██████████| 63/63 [00:02<00:00, 28.33it/s]
# Processing activities:   8%|▊         | 14/170 [00:35<05:38,  2.17s/it]
# Loading images:   0%|          | 0/54 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/54 [00:00<00:11,  4.53it/s]
# Loading images:   6%|▌         | 3/54 [00:00<00:06,  7.59it/s]
# Loading images:  24%|██▍       | 13/54 [00:00<00:01, 28.89it/s]
# Loading images:  33%|███▎      | 18/54 [00:00<00:01, 32.09it/s]
# Loading images:  41%|████      | 22/54 [00:00<00:01, 28.41it/s]
# Loading images:  54%|█████▎    | 29/54 [00:01<00:01, 23.23it/s]
# Loading images:  67%|██████▋   | 36/54 [00:01<00:00, 30.86it/s]
# Loading images:  78%|███████▊  | 42/54 [00:01<00:00, 29.71it/s]
# Loading images: 100%|██████████| 54/54 [00:01<00:00, 29.64it/s]
# Processing activities:   9%|▉         | 15/170 [00:37<05:30,  2.13s/it]
# Loading images:   0%|          | 0/45 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/45 [00:00<00:17,  2.54it/s]
# Loading images:  20%|██        | 9/45 [00:00<00:01, 21.88it/s]
# Loading images:  29%|██▉       | 13/45 [00:00<00:01, 17.87it/s]
# Loading images:  38%|███▊      | 17/45 [00:01<00:02, 11.62it/s]
# Loading images:  84%|████████▍ | 38/45 [00:01<00:00, 35.49it/s]
# Loading images: 100%|██████████| 45/45 [00:01<00:00, 25.58it/s]
# Processing activities:   9%|▉         | 16/170 [00:39<05:21,  2.09s/it]
# Loading images:   0%|          | 0/36 [00:00<?, ?it/s]
# Loading images:   3%|▎         | 1/36 [00:00<00:13,  2.54it/s]
# Loading images:  17%|█▋        | 6/36 [00:00<00:02, 12.92it/s]
# Loading images:  44%|████▍     | 16/36 [00:00<00:00, 27.90it/s]
# Loading images:  56%|█████▌    | 20/36 [00:00<00:00, 23.18it/s]
# Loading images:  78%|███████▊  | 28/36 [00:01<00:00, 31.20it/s]
# Loading images: 100%|██████████| 36/36 [00:01<00:00, 26.36it/s]
# Processing activities:  10%|█         | 17/170 [00:41<04:53,  1.92s/it]
# Loading images:   0%|          | 0/36 [00:00<?, ?it/s]
# Loading images:   3%|▎         | 1/36 [00:00<00:14,  2.40it/s]
# Loading images:  17%|█▋        | 6/36 [00:00<00:02, 11.62it/s]
# Loading images:  47%|████▋     | 17/36 [00:00<00:00, 33.77it/s]
# Loading images:  64%|██████▍   | 23/36 [00:00<00:00, 31.29it/s]
# Loading images:  78%|███████▊  | 28/36 [00:01<00:00, 28.47it/s]
# Loading images: 100%|██████████| 36/36 [00:01<00:00, 25.04it/s]
# Processing activities:  11%|█         | 18/170 [00:42<04:37,  1.82s/it]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:07,  3.68it/s]
# Loading images:   7%|▋         | 2/27 [00:00<00:04,  5.00it/s]
# Loading images:  52%|█████▏    | 14/27 [00:00<00:00, 23.93it/s]
# Loading images: 100%|██████████| 27/27 [00:01<00:00, 20.70it/s]
# Processing activities:  11%|█         | 19/170 [00:44<04:17,  1.70s/it]
# Loading images:   0%|          | 0/36 [00:00<?, ?it/s]
# Loading images:   3%|▎         | 1/36 [00:00<00:11,  2.97it/s]
# Loading images:  11%|█         | 4/36 [00:00<00:03,  9.91it/s]
# Loading images:  39%|███▉      | 14/36 [00:00<00:00, 23.37it/s]
# Loading images:  56%|█████▌    | 20/36 [00:00<00:00, 26.96it/s]
# Loading images:  64%|██████▍   | 23/36 [00:01<00:00, 18.55it/s]
# Loading images: 100%|██████████| 36/36 [00:01<00:00, 23.85it/s]
# Processing activities:  12%|█▏        | 20/170 [00:45<04:14,  1.70s/it]
# Loading images:   0%|          | 0/36 [00:00<?, ?it/s]
# Loading images:   3%|▎         | 1/36 [00:00<00:15,  2.31it/s]
# Loading images:   6%|▌         | 2/36 [00:00<00:08,  4.12it/s]
# Loading images:  14%|█▍        | 5/36 [00:00<00:03,  8.73it/s]
# Loading images:  44%|████▍     | 16/36 [00:00<00:00, 25.62it/s]
# Loading images:  53%|█████▎    | 19/36 [00:01<00:00, 18.51it/s]
# Loading images: 100%|██████████| 36/36 [00:01<00:00, 23.20it/s]
# Processing activities:  12%|█▏        | 21/170 [00:47<04:13,  1.70s/it]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:14,  1.81it/s]
# Loading images:  48%|████▊     | 13/27 [00:00<00:00, 24.56it/s]
# Loading images:  70%|███████   | 19/27 [00:00<00:00, 31.34it/s]
# Loading images: 100%|██████████| 27/27 [00:01<00:00, 25.17it/s]
# Processing activities:  13%|█▎        | 22/170 [00:48<03:50,  1.56s/it]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:10,  2.55it/s]
# Loading images:  11%|█         | 3/27 [00:00<00:05,  4.62it/s]
# Loading images:  81%|████████▏ | 22/27 [00:01<00:00, 26.28it/s]
# Loading images: 100%|██████████| 27/27 [00:01<00:00, 20.79it/s]
# Processing activities:  14%|█▎        | 23/170 [00:50<03:43,  1.52s/it]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:06,  4.21it/s]
# Loading images:  15%|█▍        | 4/27 [00:00<00:02, 11.37it/s]
# Loading images:  22%|██▏       | 6/27 [00:00<00:02,  9.42it/s]
# Loading images:  56%|█████▌    | 15/27 [00:00<00:00, 24.07it/s]
# Loading images: 100%|██████████| 27/27 [00:01<00:00, 24.38it/s]
# Processing activities:  14%|█▍        | 24/170 [00:51<03:29,  1.44s/it]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:06,  3.94it/s]
# Loading images:   7%|▋         | 2/27 [00:00<00:07,  3.55it/s]
# Loading images:  56%|█████▌    | 15/27 [00:00<00:00, 31.36it/s]
# Loading images:  78%|███████▊  | 21/27 [00:00<00:00, 34.49it/s]
# Loading images: 100%|██████████| 27/27 [00:01<00:00, 26.68it/s]
# Processing activities:  15%|█▍        | 25/170 [00:52<03:15,  1.35s/it]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:05,  5.10it/s]
# Loading images:   7%|▋         | 2/27 [00:00<00:03,  6.90it/s]
# Loading images:  11%|█         | 3/27 [00:00<00:03,  7.79it/s]
# Loading images:  15%|█▍        | 4/27 [00:00<00:05,  4.17it/s]
# Loading images: 100%|██████████| 27/27 [00:01<00:00, 25.47it/s]
# Processing activities:  15%|█▌        | 26/170 [00:53<03:07,  1.30s/it]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:08,  3.06it/s]
# Loading images:   7%|▋         | 2/27 [00:00<00:05,  4.55it/s]
# Loading images:  15%|█▍        | 4/27 [00:00<00:04,  5.22it/s]
# Loading images:  52%|█████▏    | 14/27 [00:00<00:00, 20.33it/s]
# Loading images: 100%|██████████| 27/27 [00:01<00:00, 21.93it/s]
# Processing activities:  16%|█▌        | 27/170 [00:55<03:08,  1.32s/it]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:10,  2.48it/s]
# Loading images:  33%|███▎      | 9/27 [00:00<00:00, 20.81it/s]
# Loading images:  48%|████▊     | 13/27 [00:00<00:00, 19.82it/s]
# Loading images: 100%|██████████| 27/27 [00:01<00:00, 18.48it/s]
# Processing activities:  16%|█▋        | 28/170 [00:56<03:19,  1.40s/it]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:11,  2.35it/s]
# Loading images: 100%|██████████| 27/27 [00:01<00:00, 22.92it/s]
# Processing activities:  17%|█▋        | 29/170 [00:58<03:13,  1.37s/it]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:08,  3.15it/s]
# Loading images:   7%|▋         | 2/27 [00:00<00:07,  3.31it/s]
# Loading images:  59%|█████▉    | 16/27 [00:00<00:00, 28.52it/s]
# Loading images: 100%|██████████| 27/27 [00:01<00:00, 25.92it/s]
# Processing activities:  18%|█▊        | 30/170 [00:59<03:02,  1.31s/it]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:09,  2.63it/s]
# Loading images:  48%|████▊     | 13/27 [00:00<00:00, 31.43it/s]
# Loading images:  70%|███████   | 19/27 [00:00<00:00, 25.63it/s]
# Loading images: 100%|██████████| 27/27 [00:01<00:00, 25.57it/s]
# Processing activities:  18%|█▊        | 31/170 [01:00<02:56,  1.27s/it]
# Loading images:   0%|          | 0/36 [00:00<?, ?it/s]
# Loading images:   3%|▎         | 1/36 [00:00<00:13,  2.62it/s]
# Loading images:  17%|█▋        | 6/36 [00:00<00:02, 13.81it/s]
# Loading images:  31%|███       | 11/36 [00:00<00:01, 19.47it/s]
# Loading images:  50%|█████     | 18/36 [00:00<00:00, 25.73it/s]
# Loading images:  58%|█████▊    | 21/36 [00:01<00:00, 16.78it/s]
# Loading images: 100%|██████████| 36/36 [00:01<00:00, 19.77it/s]
# Processing activities:  19%|█▉        | 32/170 [01:02<03:24,  1.48s/it]
# Loading images:   0%|          | 0/18 [00:00<?, ?it/s]
# Loading images:   6%|▌         | 1/18 [00:00<00:06,  2.75it/s]
# Loading images: 100%|██████████| 18/18 [00:00<00:00, 22.66it/s]
# Processing activities:  19%|█▉        | 33/170 [01:03<02:59,  1.31s/it]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:06,  4.32it/s]
# Loading images:   7%|▋         | 2/27 [00:00<00:05,  4.94it/s]
# Loading images:  48%|████▊     | 13/27 [00:00<00:00, 29.78it/s]
# Loading images: 100%|██████████| 27/27 [00:01<00:00, 26.85it/s]
# Processing activities:  21%|██        | 36/170 [01:04<01:44,  1.28it/s]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:06,  4.00it/s]
# Loading images:   7%|▋         | 2/27 [00:00<00:04,  5.14it/s]
# Loading images:  48%|████▊     | 13/27 [00:00<00:00, 35.97it/s]
# Loading images:  67%|██████▋   | 18/27 [00:00<00:00, 26.41it/s]
# Loading images: 100%|██████████| 27/27 [00:01<00:00, 21.37it/s]
# Processing activities:  22%|██▏       | 37/170 [01:05<02:01,  1.10it/s]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:10,  2.55it/s]
# Loading images:  37%|███▋      | 10/27 [00:00<00:01, 12.90it/s]
# Loading images: 100%|██████████| 27/27 [00:01<00:00, 21.47it/s]
# Processing activities:  22%|██▏       | 38/170 [01:07<02:15,  1.02s/it]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:11,  2.36it/s]
# Loading images:  19%|█▊        | 5/27 [00:00<00:02,  9.48it/s]
# Loading images: 100%|██████████| 27/27 [00:01<00:00, 21.88it/s]
# Processing activities:  24%|██▍       | 41/170 [01:08<01:35,  1.36it/s]
# Loading images:   0%|          | 0/36 [00:00<?, ?it/s]
# Loading images:   3%|▎         | 1/36 [00:00<00:08,  4.02it/s]
# Loading images:   6%|▌         | 2/36 [00:00<00:07,  4.48it/s]
# Loading images:  17%|█▋        | 6/36 [00:01<00:05,  5.65it/s]
# Loading images: 100%|██████████| 36/36 [00:01<00:00, 24.84it/s]
# Processing activities:  25%|██▍       | 42/170 [01:10<01:55,  1.11it/s]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:14,  1.77it/s]
# Loading images:  22%|██▏       | 6/27 [00:00<00:01, 11.31it/s]
# Loading images:  63%|██████▎   | 17/27 [00:00<00:00, 23.88it/s]
# Loading images: 100%|██████████| 27/27 [00:01<00:00, 22.99it/s]
# Processing activities:  25%|██▌       | 43/170 [01:11<02:06,  1.01it/s]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:05,  4.79it/s]
# Loading images:   7%|▋         | 2/27 [00:00<00:04,  5.14it/s]
# Loading images:  48%|████▊     | 13/27 [00:00<00:00, 29.49it/s]
# Loading images:  63%|██████▎   | 17/27 [00:00<00:00, 28.80it/s]
# Loading images: 100%|██████████| 27/27 [00:00<00:00, 28.80it/s]
# Processing activities:  26%|██▌       | 44/170 [01:12<02:07,  1.01s/it]
# Loading images:   0%|          | 0/36 [00:00<?, ?it/s]
# Loading images:   3%|▎         | 1/36 [00:00<00:06,  5.34it/s]
# Loading images:   8%|▊         | 3/36 [00:00<00:04,  7.08it/s]
# Loading images:  33%|███▎      | 12/36 [00:00<00:00, 26.22it/s]
# Loading images:  53%|█████▎    | 19/36 [00:00<00:00, 34.77it/s]
# Loading images:  67%|██████▋   | 24/36 [00:00<00:00, 36.16it/s]
# Loading images:  81%|████████  | 29/36 [00:00<00:00, 36.62it/s]
# Loading images: 100%|██████████| 36/36 [00:01<00:00, 29.48it/s]
# Processing activities:  26%|██▋       | 45/170 [01:13<02:17,  1.10s/it]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:08,  2.90it/s]
# Loading images:  26%|██▌       | 7/27 [00:00<00:01, 19.52it/s]
# Loading images:  48%|████▊     | 13/27 [00:00<00:00, 24.10it/s]
# Loading images:  74%|███████▍  | 20/27 [00:00<00:00, 25.84it/s]
# Loading images: 100%|██████████| 27/27 [00:01<00:00, 24.11it/s]
# Processing activities:  27%|██▋       | 46/170 [01:15<02:21,  1.14s/it]
# Loading images:   0%|          | 0/45 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/45 [00:00<00:16,  2.67it/s]
# Loading images:  24%|██▍       | 11/45 [00:00<00:01, 19.31it/s]
# Loading images:  38%|███▊      | 17/45 [00:01<00:02, 10.90it/s]
# Loading images: 100%|██████████| 45/45 [00:01<00:00, 26.55it/s]
# Processing activities:  28%|██▊       | 47/170 [01:17<02:45,  1.35s/it]
# Loading images:   0%|          | 0/36 [00:00<?, ?it/s]
# Loading images:   3%|▎         | 1/36 [00:00<00:15,  2.29it/s]
# Loading images:  36%|███▌      | 13/36 [00:00<00:00, 27.98it/s]
# Loading images:  50%|█████     | 18/36 [00:00<00:00, 32.08it/s]
# Loading images:  64%|██████▍   | 23/36 [00:00<00:00, 32.34it/s]
# Loading images: 100%|██████████| 36/36 [00:01<00:00, 23.95it/s]
# Processing activities:  28%|██▊       | 48/170 [01:18<02:54,  1.43s/it]
# Loading images:   0%|          | 0/45 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/45 [00:00<00:24,  1.76it/s]
# Loading images:  29%|██▉       | 13/45 [00:00<00:01, 25.50it/s]
# Loading images:  47%|████▋     | 21/45 [00:00<00:00, 32.96it/s]
# Loading images:  62%|██████▏   | 28/45 [00:01<00:00, 35.18it/s]
# Loading images:  76%|███████▌  | 34/45 [00:01<00:00, 27.93it/s]
# Loading images: 100%|██████████| 45/45 [00:01<00:00, 29.25it/s]
# Processing activities:  29%|██▉       | 49/170 [01:20<03:04,  1.52s/it]
# Loading images:   0%|          | 0/36 [00:00<?, ?it/s]
# Loading images:   3%|▎         | 1/36 [00:00<00:15,  2.25it/s]
# Loading images:  39%|███▉      | 14/36 [00:00<00:00, 27.95it/s]
# Loading images:  53%|█████▎    | 19/36 [00:00<00:00, 28.24it/s]
# Loading images:  69%|██████▉   | 25/36 [00:00<00:00, 34.89it/s]
# Loading images: 100%|██████████| 36/36 [00:01<00:00, 28.83it/s]
# Processing activities:  29%|██▉       | 50/170 [01:21<02:58,  1.49s/it]
# Loading images:   0%|          | 0/45 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/45 [00:00<00:18,  2.44it/s]
# Loading images:  20%|██        | 9/45 [00:00<00:01, 22.45it/s]
# Loading images:  33%|███▎      | 15/45 [00:00<00:00, 32.44it/s]
# Loading images:  47%|████▋     | 21/45 [00:00<00:00, 25.16it/s]
# Loading images:  62%|██████▏   | 28/45 [00:01<00:00, 33.38it/s]
# Loading images:  73%|███████▎  | 33/45 [00:01<00:00, 23.76it/s]
# Loading images:  91%|█████████ | 41/45 [00:01<00:00, 29.25it/s]
# Loading images: 100%|██████████| 45/45 [00:01<00:00, 25.38it/s]
# Processing activities:  30%|███       | 51/170 [01:23<03:13,  1.63s/it]
# Loading images:   0%|          | 0/54 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/54 [00:00<00:21,  2.48it/s]
# Loading images:  19%|█▊        | 10/54 [00:00<00:01, 23.37it/s]
# Loading images:  28%|██▊       | 15/54 [00:00<00:01, 23.90it/s]
# Loading images:  37%|███▋      | 20/54 [00:00<00:01, 28.27it/s]
# Loading images:  44%|████▍     | 24/54 [00:01<00:01, 20.40it/s]
# Loading images:  67%|██████▋   | 36/54 [00:01<00:00, 29.18it/s]
# Loading images:  76%|███████▌  | 41/54 [00:01<00:00, 27.40it/s]
# Loading images: 100%|██████████| 54/54 [00:01<00:00, 28.98it/s]
# Processing activities:  31%|███       | 52/170 [01:25<03:29,  1.78s/it]
# Loading images:   0%|          | 0/36 [00:00<?, ?it/s]
# Loading images:   3%|▎         | 1/36 [00:00<00:14,  2.42it/s]
# Loading images:  19%|█▉        | 7/36 [00:00<00:02, 14.15it/s]
# Loading images:  44%|████▍     | 16/36 [00:00<00:00, 29.85it/s]
# Loading images:  58%|█████▊    | 21/36 [00:00<00:00, 30.33it/s]
# Loading images:  69%|██████▉   | 25/36 [00:01<00:00, 28.65it/s]
# Loading images:  81%|████████  | 29/36 [00:01<00:00, 25.86it/s]
# Loading images: 100%|██████████| 36/36 [00:01<00:00, 24.11it/s]
# Processing activities:  31%|███       | 53/170 [01:27<03:23,  1.74s/it]
# Loading images:   0%|          | 0/45 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/45 [00:00<00:15,  2.80it/s]
# Loading images:  20%|██        | 9/45 [00:00<00:02, 15.73it/s]
# Loading images:  33%|███▎      | 15/45 [00:01<00:02, 12.08it/s]
# Loading images:  80%|████████  | 36/45 [00:01<00:00, 33.96it/s]
# Loading images: 100%|██████████| 45/45 [00:01<00:00, 26.83it/s]
# Processing activities:  32%|███▏      | 54/170 [01:29<03:26,  1.78s/it]
# Loading images:   0%|          | 0/45 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/45 [00:00<00:17,  2.51it/s]
# Loading images:  29%|██▉       | 13/45 [00:00<00:01, 31.58it/s]
# Loading images:  42%|████▏     | 19/45 [00:00<00:01, 24.75it/s]
# Loading images:  56%|█████▌    | 25/45 [00:00<00:00, 28.53it/s]
# Loading images:  64%|██████▍   | 29/45 [00:01<00:00, 25.70it/s]
# Loading images:  80%|████████  | 36/45 [00:01<00:00, 26.96it/s]
# Loading images: 100%|██████████| 45/45 [00:01<00:00, 25.44it/s]
# Processing activities:  32%|███▏      | 55/170 [01:31<03:31,  1.84s/it]
# Loading images:   0%|          | 0/54 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/54 [00:00<00:17,  3.04it/s]
# Loading images:  11%|█         | 6/54 [00:00<00:02, 17.18it/s]
# Loading images:  24%|██▍       | 13/54 [00:00<00:01, 27.78it/s]
# Loading images:  31%|███▏      | 17/54 [00:00<00:01, 25.13it/s]
# Loading images:  44%|████▍     | 24/54 [00:01<00:01, 27.83it/s]
# Loading images:  57%|█████▋    | 31/54 [00:01<00:00, 31.72it/s]
# Loading images:  67%|██████▋   | 36/54 [00:01<00:00, 31.51it/s]
# Loading images: 100%|██████████| 54/54 [00:01<00:00, 30.13it/s]
# Processing activities:  33%|███▎      | 56/170 [01:33<03:36,  1.90s/it]
# Loading images:   0%|          | 0/63 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/63 [00:00<00:19,  3.17it/s]
# Loading images:   8%|▊         | 5/63 [00:00<00:04, 12.72it/s]
# Loading images:  22%|██▏       | 14/63 [00:00<00:02, 17.27it/s]
# Loading images:  40%|███▉      | 25/63 [00:01<00:01, 27.07it/s]
# Loading images:  48%|████▊     | 30/63 [00:01<00:01, 29.25it/s]
# Loading images:  57%|█████▋    | 36/63 [00:01<00:01, 23.75it/s]
# Loading images:  75%|███████▍  | 47/63 [00:01<00:00, 28.74it/s]
# Loading images:  86%|████████▌ | 54/63 [00:02<00:00, 33.42it/s]
# Loading images: 100%|██████████| 63/63 [00:02<00:00, 28.54it/s]
# Processing activities:  34%|███▎      | 57/170 [01:36<03:54,  2.07s/it]
# Loading images:   0%|          | 0/54 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/54 [00:00<00:42,  1.25it/s]
# Loading images:  37%|███▋      | 20/54 [00:00<00:01, 29.51it/s]
# Loading images:  57%|█████▋    | 31/54 [00:01<00:00, 30.99it/s]
# Loading images:  72%|███████▏  | 39/54 [00:01<00:00, 30.41it/s]
# Loading images: 100%|██████████| 54/54 [00:02<00:00, 23.58it/s]
# Processing activities:  34%|███▍      | 58/170 [01:38<04:07,  2.21s/it]
# Loading images:   0%|          | 0/36 [00:00<?, ?it/s]
# Loading images:   3%|▎         | 1/36 [00:00<00:21,  1.62it/s]
# Loading images:  42%|████▏     | 15/36 [00:00<00:00, 25.99it/s]
# Loading images:  64%|██████▍   | 23/36 [00:00<00:00, 35.05it/s]
# Loading images: 100%|██████████| 36/36 [00:01<00:00, 27.90it/s]
# Processing activities:  35%|███▍      | 59/170 [01:40<03:41,  1.99s/it]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:05,  4.91it/s]
# Loading images:   7%|▋         | 2/27 [00:00<00:03,  6.28it/s]
# Loading images:  37%|███▋      | 10/27 [00:00<00:00, 27.37it/s]
# Loading images:  48%|████▊     | 13/27 [00:00<00:00, 27.54it/s]
# Loading images:  59%|█████▉    | 16/27 [00:00<00:00, 25.46it/s]
# Loading images:  70%|███████   | 19/27 [00:00<00:00, 25.10it/s]
# Loading images: 100%|██████████| 27/27 [00:01<00:00, 26.01it/s]
# Processing activities:  35%|███▌      | 60/170 [01:41<03:12,  1.75s/it]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:11,  2.35it/s]
# Loading images:  52%|█████▏    | 14/27 [00:00<00:00, 25.34it/s]
# Loading images:  67%|██████▋   | 18/27 [00:01<00:00, 14.69it/s]
# Loading images: 100%|██████████| 27/27 [00:03<00:00,  6.96it/s]
# Processing activities:  36%|███▌      | 61/170 [01:45<04:24,  2.43s/it]
# Loading images:   0%|          | 0/36 [00:00<?, ?it/s]
# Loading images:   3%|▎         | 1/36 [00:00<00:11,  3.12it/s]
# Loading images:  19%|█▉        | 7/36 [00:01<00:04,  6.57it/s]
# Loading images:  47%|████▋     | 17/36 [00:01<00:01, 15.78it/s]
# Loading images: 100%|██████████| 36/36 [00:02<00:00, 15.91it/s]
# Processing activities:  36%|███▋      | 62/170 [01:47<04:22,  2.43s/it]
# Loading images:   0%|          | 0/36 [00:00<?, ?it/s]
# Loading images:   3%|▎         | 1/36 [00:00<00:12,  2.83it/s]
# Loading images:  11%|█         | 4/36 [00:00<00:04,  6.97it/s]
# Loading images:  53%|█████▎    | 19/36 [00:00<00:00, 30.57it/s]
# Loading images:  69%|██████▉   | 25/36 [00:01<00:00, 31.27it/s]
# Loading images: 100%|██████████| 36/36 [00:01<00:00, 27.94it/s]
# Processing activities:  37%|███▋      | 63/170 [01:49<03:49,  2.14s/it]
# Loading images:   0%|          | 0/45 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/45 [00:00<00:08,  5.06it/s]
# Loading images:   4%|▍         | 2/45 [00:00<00:08,  4.93it/s]
# Loading images:  11%|█         | 5/45 [00:00<00:05,  7.29it/s]
# Loading images:  38%|███▊      | 17/45 [00:00<00:00, 28.58it/s]
# Loading images:  58%|█████▊    | 26/45 [00:01<00:00, 26.90it/s]
# Loading images:  82%|████████▏ | 37/45 [00:01<00:00, 40.21it/s]
# Loading images: 100%|██████████| 45/45 [00:01<00:00, 28.09it/s]
# Processing activities:  38%|███▊      | 64/170 [01:50<03:37,  2.05s/it]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:09,  2.67it/s]
# Loading images:  37%|███▋      | 10/27 [00:00<00:00, 25.14it/s]
# Loading images:  56%|█████▌    | 15/27 [00:00<00:00, 24.34it/s]
# Loading images:  74%|███████▍  | 20/27 [00:00<00:00, 28.37it/s]
# Loading images: 100%|██████████| 27/27 [00:01<00:00, 25.88it/s]
# Processing activities:  38%|███▊      | 65/170 [01:52<03:07,  1.79s/it]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:10,  2.46it/s]
# Loading images:  15%|█▍        | 4/27 [00:00<00:02,  9.58it/s]
# Loading images:  56%|█████▌    | 15/27 [00:00<00:00, 23.91it/s]
# Loading images: 100%|██████████| 27/27 [00:01<00:00, 26.28it/s]
# Processing activities:  39%|███▉      | 66/170 [01:53<02:46,  1.60s/it]
# Loading images:   0%|          | 0/18 [00:00<?, ?it/s]
# Loading images:   6%|▌         | 1/18 [00:00<00:07,  2.23it/s]
# Loading images:  28%|██▊       | 5/18 [00:00<00:01, 10.90it/s]
# Loading images:  56%|█████▌    | 10/18 [00:00<00:00, 20.41it/s]
# Loading images: 100%|██████████| 18/18 [00:01<00:00, 17.29it/s]
# Processing activities:  39%|███▉      | 67/170 [01:54<02:31,  1.47s/it]
# Loading images:   0%|          | 0/45 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/45 [00:00<00:10,  4.13it/s]
# Loading images:   7%|▋         | 3/45 [00:00<00:05,  7.63it/s]
# Loading images:  29%|██▉       | 13/45 [00:00<00:00, 32.12it/s]
# Loading images:  40%|████      | 18/45 [00:00<00:01, 26.51it/s]
# Loading images:  60%|██████    | 27/45 [00:00<00:00, 38.05it/s]
# Loading images:  71%|███████   | 32/45 [00:01<00:00, 26.83it/s]
# Loading images:  89%|████████▉ | 40/45 [00:01<00:00, 28.85it/s]
# Loading images: 100%|██████████| 45/45 [00:01<00:00, 25.81it/s]
# Processing activities:  40%|████      | 68/170 [01:56<02:44,  1.61s/it]
# Loading images:   0%|          | 0/45 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/45 [00:00<00:24,  1.80it/s]
# Loading images:  31%|███       | 14/45 [00:00<00:01, 26.13it/s]
# Loading images:  44%|████▍     | 20/45 [00:00<00:00, 27.15it/s]
# Loading images:  56%|█████▌    | 25/45 [00:01<00:00, 31.49it/s]
# Loading images:  67%|██████▋   | 30/45 [00:01<00:00, 26.44it/s]
# Loading images:  78%|███████▊  | 35/45 [00:01<00:00, 30.89it/s]
# Loading images: 100%|██████████| 45/45 [00:01<00:00, 28.68it/s]
# Processing activities:  41%|████      | 69/170 [01:58<02:47,  1.66s/it]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:05,  5.10it/s]
# Loading images:   7%|▋         | 2/27 [00:00<00:05,  4.71it/s]
# Loading images:  22%|██▏       | 6/27 [00:00<00:01, 13.61it/s]
# Loading images:  56%|█████▌    | 15/27 [00:00<00:00, 33.04it/s]
# Loading images: 100%|██████████| 27/27 [00:00<00:00, 28.88it/s]
# Processing activities:  41%|████      | 70/170 [01:59<02:28,  1.49s/it]
# Loading images:   0%|          | 0/18 [00:00<?, ?it/s]
# Loading images:   6%|▌         | 1/18 [00:00<00:06,  2.56it/s]
# Loading images:  67%|██████▋   | 12/18 [00:00<00:00, 28.92it/s]
# Loading images: 100%|██████████| 18/18 [00:00<00:00, 22.39it/s]
# Processing activities:  42%|████▏     | 71/170 [02:00<02:09,  1.31s/it]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:10,  2.40it/s]
# Loading images:  48%|████▊     | 13/27 [00:00<00:00, 23.39it/s]
# Loading images:  67%|██████▋   | 18/27 [00:00<00:00, 26.66it/s]
# Loading images: 100%|██████████| 27/27 [00:01<00:00, 26.20it/s]
# Processing activities:  42%|████▏     | 72/170 [02:01<02:04,  1.27s/it]
# Loading images:   0%|          | 0/18 [00:00<?, ?it/s]
# Loading images:   6%|▌         | 1/18 [00:00<00:06,  2.58it/s]
# Loading images: 100%|██████████| 18/18 [00:00<00:00, 22.98it/s]
# Processing activities:  43%|████▎     | 73/170 [02:02<01:51,  1.15s/it]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:12,  2.02it/s]
# Loading images:  59%|█████▉    | 16/27 [00:00<00:00, 25.60it/s]
# Loading images:  81%|████████▏ | 22/27 [00:00<00:00, 31.40it/s]
# Loading images: 100%|██████████| 27/27 [00:01<00:00, 25.82it/s]
# Processing activities:  44%|████▎     | 74/170 [02:03<01:51,  1.16s/it]
# Loading images:   0%|          | 0/18 [00:00<?, ?it/s]
# Loading images: 100%|██████████| 18/18 [00:00<00:00, 23.45it/s]
# Processing activities:  44%|████▍     | 75/170 [02:04<01:41,  1.07s/it]
# Loading images:   0%|          | 0/36 [00:00<?, ?it/s]
# Loading images:   3%|▎         | 1/36 [00:00<00:15,  2.28it/s]
# Loading images:  39%|███▉      | 14/36 [00:00<00:00, 23.97it/s]
# Loading images:  47%|████▋     | 17/36 [00:00<00:00, 23.67it/s]
# Loading images:  72%|███████▏  | 26/36 [00:01<00:00, 30.32it/s]
# Loading images:  83%|████████▎ | 30/36 [00:01<00:00, 32.17it/s]
# Loading images: 100%|██████████| 36/36 [00:01<00:00, 26.61it/s]
# Processing activities:  45%|████▍     | 76/170 [02:05<01:53,  1.21s/it]
# Loading images:   0%|          | 0/18 [00:00<?, ?it/s]
# Loading images:   6%|▌         | 1/18 [00:00<00:08,  2.11it/s]
# Loading images: 100%|██████████| 18/18 [00:00<00:00, 21.48it/s]
# Processing activities:  45%|████▌     | 77/170 [02:06<01:44,  1.13s/it]
# Loading images:   0%|          | 0/18 [00:00<?, ?it/s]
# Loading images:   6%|▌         | 1/18 [00:00<00:06,  2.56it/s]
# Loading images:  78%|███████▊  | 14/18 [00:00<00:00, 27.00it/s]
# Loading images: 100%|██████████| 18/18 [00:00<00:00, 20.29it/s]
# Processing activities:  46%|████▌     | 78/170 [02:07<01:40,  1.09s/it]
# Loading images:   0%|          | 0/18 [00:00<?, ?it/s]
# Loading images:   6%|▌         | 1/18 [00:00<00:04,  4.23it/s]
# Loading images:  17%|█▋        | 3/18 [00:00<00:02,  7.19it/s]
# Loading images:  78%|███████▊  | 14/18 [00:00<00:00, 31.48it/s]
# Loading images: 100%|██████████| 18/18 [00:00<00:00, 21.75it/s]
# Processing activities:  46%|████▋     | 79/170 [02:08<01:34,  1.04s/it]
# Loading images:   0%|          | 0/54 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/54 [00:00<00:18,  2.89it/s]
# Loading images:   4%|▎         | 2/54 [00:00<00:10,  4.87it/s]
# Loading images:  24%|██▍       | 13/54 [00:00<00:01, 24.28it/s]
# Loading images:  35%|███▌      | 19/54 [00:00<00:01, 28.07it/s]
# Loading images:  44%|████▍     | 24/54 [00:00<00:00, 32.71it/s]
# Loading images:  52%|█████▏    | 28/54 [00:01<00:00, 30.05it/s]
# Loading images:  59%|█████▉    | 32/54 [00:01<00:00, 26.90it/s]
# Loading images:  74%|███████▍  | 40/54 [00:01<00:00, 33.37it/s]
# Loading images:  81%|████████▏ | 44/54 [00:01<00:00, 27.80it/s]
# Loading images:  91%|█████████ | 49/54 [00:01<00:00, 24.27it/s]
# Loading images: 100%|██████████| 54/54 [00:02<00:00, 22.23it/s]
# Processing activities:  47%|████▋     | 80/170 [02:11<02:18,  1.53s/it]
# Loading images:   0%|          | 0/45 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/45 [00:00<00:13,  3.33it/s]
# Loading images:  11%|█         | 5/45 [00:00<00:02, 14.89it/s]
# Loading images:  29%|██▉       | 13/45 [00:00<00:01, 23.24it/s]
# Loading images:  36%|███▌      | 16/45 [00:00<00:01, 23.91it/s]
# Loading images:  44%|████▍     | 20/45 [00:01<00:01, 21.12it/s]
# Loading images:  67%|██████▋   | 30/45 [00:01<00:00, 34.99it/s]
# Loading images:  78%|███████▊  | 35/45 [00:01<00:00, 26.07it/s]
# Loading images: 100%|██████████| 45/45 [00:01<00:00, 27.54it/s]
# Processing activities:  48%|████▊     | 81/170 [02:13<02:25,  1.63s/it]
# Loading images:   0%|          | 0/36 [00:00<?, ?it/s]
# Loading images:   3%|▎         | 1/36 [00:00<00:13,  2.50it/s]
# Loading images:   8%|▊         | 3/36 [00:00<00:05,  6.30it/s]
# Loading images:  36%|███▌      | 13/36 [00:00<00:00, 24.28it/s]
# Loading images:  47%|████▋     | 17/36 [00:00<00:00, 27.44it/s]
# Loading images:  67%|██████▋   | 24/36 [00:00<00:00, 37.28it/s]
# Loading images:  81%|████████  | 29/36 [00:01<00:00, 29.25it/s]
# Loading images: 100%|██████████| 36/36 [00:01<00:00, 22.55it/s]
# Processing activities:  48%|████▊     | 82/170 [02:14<02:27,  1.68s/it]
# Loading images:   0%|          | 0/36 [00:00<?, ?it/s]
# Loading images:   3%|▎         | 1/36 [00:00<00:08,  4.30it/s]
# Loading images:   6%|▌         | 2/36 [00:00<00:05,  5.84it/s]
# Loading images:  31%|███       | 11/36 [00:00<00:01, 20.59it/s]
# Loading images:  39%|███▉      | 14/36 [00:01<00:01, 13.57it/s]
# Loading images: 100%|██████████| 36/36 [00:01<00:00, 25.85it/s]
# Processing activities:  49%|████▉     | 83/170 [02:16<02:23,  1.65s/it]
# Loading images:   0%|          | 0/45 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/45 [00:00<00:17,  2.49it/s]
# Loading images:  29%|██▉       | 13/45 [00:00<00:01, 28.34it/s]
# Loading images:  40%|████      | 18/45 [00:00<00:00, 27.40it/s]
# Loading images:  56%|█████▌    | 25/45 [00:00<00:00, 36.26it/s]
# Loading images:  67%|██████▋   | 30/45 [00:01<00:00, 26.03it/s]
# Loading images:  82%|████████▏ | 37/45 [00:01<00:00, 34.03it/s]
# Loading images: 100%|██████████| 45/45 [00:01<00:00, 27.10it/s]
# Processing activities:  49%|████▉     | 84/170 [02:18<02:27,  1.71s/it]
# Loading images:   0%|          | 0/18 [00:00<?, ?it/s]
# Loading images:   6%|▌         | 1/18 [00:00<00:08,  2.05it/s]
# Loading images:  11%|█         | 2/18 [00:00<00:05,  2.94it/s]
# Loading images: 100%|██████████| 18/18 [00:01<00:00, 16.30it/s]
# Processing activities:  50%|█████     | 85/170 [02:19<02:12,  1.56s/it]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:11,  2.26it/s]
# Loading images:  11%|█         | 3/27 [00:00<00:03,  6.50it/s]
# Loading images: 100%|██████████| 27/27 [00:02<00:00, 11.95it/s]
# Processing activities:  52%|█████▏    | 88/170 [02:22<01:32,  1.13s/it]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:05,  5.12it/s]
# Loading images:   7%|▋         | 2/27 [00:00<00:04,  5.24it/s]
# Loading images:  15%|█▍        | 4/27 [00:00<00:04,  5.24it/s]
# Loading images: 100%|██████████| 27/27 [00:01<00:00, 24.18it/s]
# Processing activities:  52%|█████▏    | 89/170 [02:23<01:33,  1.16s/it]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:06,  4.27it/s]
# Loading images:   7%|▋         | 2/27 [00:00<00:05,  4.81it/s]
# Loading images:  30%|██▉       | 8/27 [00:00<00:00, 19.63it/s]
# Loading images:  41%|████      | 11/27 [00:00<00:00, 21.63it/s]
# Loading images:  52%|█████▏    | 14/27 [00:00<00:00, 22.35it/s]
# Loading images: 100%|██████████| 27/27 [00:01<00:00, 22.69it/s]
# Processing activities:  53%|█████▎    | 90/170 [02:24<01:35,  1.20s/it]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:10,  2.40it/s]
# Loading images:  30%|██▉       | 8/27 [00:00<00:01, 14.85it/s]
# Loading images: 100%|██████████| 27/27 [00:01<00:00, 22.46it/s]
# Processing activities:  54%|█████▎    | 91/170 [02:25<01:37,  1.23s/it]
# Loading images:   0%|          | 0/18 [00:00<?, ?it/s]
# Loading images:   6%|▌         | 1/18 [00:00<00:07,  2.40it/s]
# Loading images:  72%|███████▏  | 13/18 [00:00<00:00, 22.54it/s]
# Loading images: 100%|██████████| 18/18 [00:01<00:00, 16.57it/s]
# Processing activities:  54%|█████▍    | 92/170 [02:27<01:35,  1.22s/it]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:09,  2.61it/s]
# Loading images:  37%|███▋      | 10/27 [00:00<00:01, 14.48it/s]
# Loading images: 100%|██████████| 27/27 [00:01<00:00, 26.70it/s]
# Processing activities:  55%|█████▍    | 93/170 [02:28<01:32,  1.20s/it]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:10,  2.42it/s]
# Loading images:  48%|████▊     | 13/27 [00:00<00:00, 25.24it/s]
# Loading images:  63%|██████▎   | 17/27 [00:00<00:00, 24.32it/s]
# Loading images:  74%|███████▍  | 20/27 [00:01<00:00, 20.97it/s]
# Loading images: 100%|██████████| 27/27 [00:01<00:00, 22.90it/s]
# Processing activities:  55%|█████▌    | 94/170 [02:29<01:33,  1.24s/it]
# Loading images:   0%|          | 0/36 [00:00<?, ?it/s]
# Loading images:   3%|▎         | 1/36 [00:00<00:14,  2.40it/s]
# Loading images:  25%|██▌       | 9/36 [00:00<00:01, 16.26it/s]
# Loading images: 100%|██████████| 36/36 [00:01<00:00, 26.55it/s]
# Processing activities:  56%|█████▌    | 95/170 [02:31<01:39,  1.32s/it]
# Loading images:   0%|          | 0/18 [00:00<?, ?it/s]
# Loading images:   6%|▌         | 1/18 [00:00<00:07,  2.37it/s]
# Loading images:  44%|████▍     | 8/18 [00:00<00:00, 18.54it/s]
# Loading images: 100%|██████████| 18/18 [00:02<00:00,  6.52it/s]
# Processing activities:  58%|█████▊    | 99/170 [02:34<01:07,  1.06it/s]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:10,  2.47it/s]
# Loading images:  52%|█████▏    | 14/27 [00:00<00:00, 34.05it/s]
# Loading images: 100%|██████████| 27/27 [00:00<00:00, 30.08it/s]
# Processing activities:  59%|█████▉    | 100/170 [02:35<01:07,  1.04it/s]
# Loading images:   0%|          | 0/36 [00:00<?, ?it/s]
# Loading images:   3%|▎         | 1/36 [00:00<00:12,  2.87it/s]
# Loading images:   8%|▊         | 3/36 [00:00<00:04,  7.23it/s]
# Loading images:  14%|█▍        | 5/36 [00:00<00:03,  9.70it/s]
# Loading images: 100%|██████████| 36/36 [00:06<00:00,  5.60it/s]
# Processing activities:  59%|█████▉    | 101/170 [02:41<02:26,  2.12s/it]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:19,  1.33it/s]
# Loading images: 100%|██████████| 27/27 [00:01<00:00, 26.98it/s]
# Processing activities:  60%|██████    | 102/170 [02:42<02:09,  1.90s/it]
# Loading images:   0%|          | 0/36 [00:00<?, ?it/s]
# Loading images:   3%|▎         | 1/36 [00:00<00:14,  2.50it/s]
# Loading images:   8%|▊         | 3/36 [00:00<00:06,  4.72it/s]
# Loading images:  11%|█         | 4/36 [00:00<00:05,  5.73it/s]
# Loading images:  56%|█████▌    | 20/36 [00:01<00:00, 32.19it/s]
# Loading images:  72%|███████▏  | 26/36 [00:01<00:00, 36.67it/s]
# Loading images:  86%|████████▌ | 31/36 [00:01<00:00, 36.53it/s]
# Loading images: 100%|██████████| 36/36 [00:01<00:00, 24.35it/s]
# Processing activities:  61%|██████    | 103/170 [02:44<02:03,  1.84s/it]
# Loading images:   0%|          | 0/36 [00:00<?, ?it/s]
# Loading images:   3%|▎         | 1/36 [00:00<00:04,  7.83it/s]
# Loading images:   8%|▊         | 3/36 [00:00<00:03,  9.09it/s]
# Loading images:  19%|█▉        | 7/36 [00:00<00:01, 16.87it/s]
# Loading images:  36%|███▌      | 13/36 [00:00<00:00, 28.02it/s]
# Loading images:  47%|████▋     | 17/36 [00:00<00:00, 30.10it/s]
# Loading images:  58%|█████▊    | 21/36 [00:00<00:00, 28.50it/s]
# Loading images:  75%|███████▌  | 27/36 [00:00<00:00, 36.55it/s]
# Loading images: 100%|██████████| 36/36 [00:01<00:00, 29.17it/s]
# Processing activities:  61%|██████    | 104/170 [02:45<01:56,  1.76s/it]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:07,  3.45it/s]
# Loading images:   7%|▋         | 2/27 [00:00<00:04,  5.43it/s]
# Loading images: 100%|██████████| 27/27 [00:01<00:00, 25.51it/s]
# Processing activities:  62%|██████▏   | 105/170 [02:47<01:44,  1.61s/it]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:05,  4.51it/s]
# Loading images:   7%|▋         | 2/27 [00:00<00:06,  3.82it/s]
# Loading images:  48%|████▊     | 13/27 [00:00<00:00, 25.03it/s]
# Loading images:  74%|███████▍  | 20/27 [00:00<00:00, 33.81it/s]
# Loading images: 100%|██████████| 27/27 [00:01<00:00, 24.57it/s]
# Processing activities:  62%|██████▏   | 106/170 [02:48<01:36,  1.51s/it]
# Loading images:   0%|          | 0/18 [00:00<?, ?it/s]
# Loading images:   6%|▌         | 1/18 [00:00<00:07,  2.39it/s]
# Loading images:  33%|███▎      | 6/18 [00:00<00:01,  9.50it/s]
# Loading images: 100%|██████████| 18/18 [00:01<00:00, 17.58it/s]
# Processing activities:  63%|██████▎   | 107/170 [02:49<01:28,  1.40s/it]
# Loading images:   0%|          | 0/36 [00:00<?, ?it/s]
# Loading images:   3%|▎         | 1/36 [00:00<00:11,  2.98it/s]
# Loading images:  28%|██▊       | 10/36 [00:00<00:01, 25.79it/s]
# Loading images:  39%|███▉      | 14/36 [00:00<00:00, 28.81it/s]
# Loading images:  50%|█████     | 18/36 [00:00<00:00, 29.62it/s]
# Loading images:  61%|██████    | 22/36 [00:00<00:00, 29.61it/s]
# Loading images:  78%|███████▊  | 28/36 [00:01<00:00, 25.52it/s]
# Loading images: 100%|██████████| 36/36 [00:01<00:00, 26.59it/s]
# Processing activities:  64%|██████▎   | 108/170 [02:51<01:29,  1.44s/it]
# Loading images:   0%|          | 0/45 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/45 [00:00<00:08,  5.20it/s]
# Loading images:   4%|▍         | 2/45 [00:00<00:07,  5.53it/s]
# Loading images:  13%|█▎        | 6/45 [00:00<00:02, 16.12it/s]
# Loading images:  29%|██▉       | 13/45 [00:00<00:01, 31.17it/s]
# Loading images:  38%|███▊      | 17/45 [00:00<00:01, 26.87it/s]
# Loading images:  47%|████▋     | 21/45 [00:00<00:00, 24.13it/s]
# Loading images:  62%|██████▏   | 28/45 [00:01<00:00, 30.15it/s]
# Loading images: 100%|██████████| 45/45 [00:01<00:00, 25.90it/s]
# Processing activities:  64%|██████▍   | 109/170 [02:53<01:37,  1.59s/it]
# Loading images:   0%|          | 0/45 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/45 [00:00<00:18,  2.34it/s]
# Loading images:   7%|▋         | 3/45 [00:01<00:16,  2.55it/s]
# Loading images: 100%|██████████| 45/45 [00:01<00:00, 27.47it/s]
# Processing activities:  65%|██████▍   | 110/170 [02:54<01:40,  1.68s/it]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:14,  1.77it/s]
# Loading images:  56%|█████▌    | 15/27 [00:00<00:00, 24.96it/s]
# Loading images:  74%|███████▍  | 20/27 [00:00<00:00, 27.45it/s]
# Loading images: 100%|██████████| 27/27 [00:01<00:00, 19.94it/s]
# Processing activities:  65%|██████▌   | 111/170 [02:56<01:35,  1.63s/it]
# Loading images:   0%|          | 0/18 [00:00<?, ?it/s]
# Loading images:   6%|▌         | 1/18 [00:00<00:08,  2.08it/s]
# Loading images:  56%|█████▌    | 10/18 [00:00<00:00, 18.39it/s]
# Loading images: 100%|██████████| 18/18 [00:00<00:00, 20.33it/s]
# Processing activities:  66%|██████▌   | 112/170 [02:57<01:23,  1.44s/it]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:10,  2.40it/s]
# Loading images:  19%|█▊        | 5/27 [00:00<00:01, 11.77it/s]
# Loading images:  52%|█████▏    | 14/27 [00:00<00:00, 27.52it/s]
# Loading images:  67%|██████▋   | 18/27 [00:00<00:00, 22.70it/s]
# Loading images: 100%|██████████| 27/27 [00:01<00:00, 25.69it/s]
# Processing activities:  66%|██████▋   | 113/170 [02:58<01:17,  1.36s/it]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:01<00:39,  1.53s/it]
# Loading images: 100%|██████████| 27/27 [00:01<00:00, 14.68it/s]
# Processing activities:  67%|██████▋   | 114/170 [03:00<01:26,  1.55s/it]
# Loading images:   0%|          | 0/45 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/45 [00:00<00:12,  3.41it/s]
# Loading images:   4%|▍         | 2/45 [00:00<00:08,  5.36it/s]
# Loading images:  16%|█▌        | 7/45 [00:00<00:02, 18.70it/s]
# Loading images: 100%|██████████| 45/45 [00:01<00:00, 27.56it/s]
# Processing activities:  68%|██████▊   | 115/170 [03:02<01:30,  1.64s/it]
# ...
# Loading images: 100%|██████████| 63/63 [00:02<00:00, 25.27it/s]
# Processing activities:  79%|███████▉  | 134/170 [03:39<01:30,  2.50s/it]
# Loading images:   0%|          | 0/18 [00:00<?, ?it/s]
# Loading images:   6%|▌         | 1/18 [00:00<00:07,  2.28it/s]
# Loading images:  22%|██▏       | 4/18 [00:00<00:01,  8.22it/s]
# Loading images: 100%|██████████| 18/18 [00:00<00:00, 19.35it/s]
# Processing activities:  80%|████████  | 136/170 [03:40<00:53,  1.58s/it]
# Loading images:   0%|          | 0/18 [00:00<?, ?it/s]
# Loading images:   6%|▌         | 1/18 [00:00<00:04,  3.78it/s]
# Loading images:  28%|██▊       | 5/18 [00:00<00:00, 14.57it/s]
# Loading images:  72%|███████▏  | 13/18 [00:00<00:00, 23.79it/s]
# Loading images: 100%|██████████| 18/18 [00:00<00:00, 23.30it/s]
# Processing activities:  81%|████████  | 138/170 [03:41<00:36,  1.13s/it]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:12,  2.09it/s]
# Loading images:  48%|████▊     | 13/27 [00:00<00:00, 24.40it/s]
# Loading images:  67%|██████▋   | 18/27 [00:00<00:00, 27.42it/s]
# Loading images: 100%|██████████| 27/27 [00:01<00:00, 25.97it/s]
# Processing activities:  82%|████████▏ | 139/170 [03:43<00:35,  1.14s/it]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:10,  2.52it/s]
# Loading images:  48%|████▊     | 13/27 [00:00<00:00, 23.83it/s]
# Loading images:  74%|███████▍  | 20/27 [00:00<00:00, 31.05it/s]
# Loading images: 100%|██████████| 27/27 [00:01<00:00, 26.14it/s]
# Processing activities:  82%|████████▏ | 140/170 [03:44<00:34,  1.15s/it]
# Loading images:   0%|          | 0/36 [00:00<?, ?it/s]
# Loading images:   3%|▎         | 1/36 [00:00<00:11,  2.94it/s]
# Loading images:   6%|▌         | 2/36 [00:00<00:07,  4.42it/s]
# Loading images:  39%|███▉      | 14/36 [00:00<00:00, 26.39it/s]
# Loading images:  58%|█████▊    | 21/36 [00:00<00:00, 34.53it/s]
# Loading images:  69%|██████▉   | 25/36 [00:01<00:00, 29.27it/s]
# Loading images:  81%|████████  | 29/36 [00:01<00:00, 30.18it/s]
# Loading images: 100%|██████████| 36/36 [00:01<00:00, 27.93it/s]
# Processing activities:  83%|████████▎ | 141/170 [03:45<00:35,  1.23s/it]
# Loading images:   0%|          | 0/36 [00:00<?, ?it/s]
# Loading images:   3%|▎         | 1/36 [00:00<00:11,  3.15it/s]
# Loading images:   8%|▊         | 3/36 [00:00<00:04,  7.69it/s]
# Loading images:  33%|███▎      | 12/36 [00:00<00:00, 25.90it/s]
# Loading images:  42%|████▏     | 15/36 [00:00<00:00, 26.73it/s]
# Loading images:  50%|█████     | 18/36 [00:00<00:00, 25.62it/s]
# Loading images:  69%|██████▉   | 25/36 [00:00<00:00, 36.87it/s]
# Loading images:  83%|████████▎ | 30/36 [00:01<00:00, 25.43it/s]
# Loading images: 100%|██████████| 36/36 [00:01<00:00, 25.97it/s]
# Processing activities:  84%|████████▎ | 142/170 [03:47<00:36,  1.32s/it]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:10,  2.44it/s]
# Loading images:  30%|██▉       | 8/27 [00:00<00:01, 14.73it/s]
# Loading images:  59%|█████▉    | 16/27 [00:00<00:00, 26.59it/s]
# Loading images: 100%|██████████| 27/27 [00:01<00:00, 22.02it/s]
# Processing activities:  84%|████████▍ | 143/170 [03:48<00:35,  1.33s/it]
# Loading images:   0%|          | 0/18 [00:00<?, ?it/s]
# Loading images:   6%|▌         | 1/18 [00:00<00:03,  4.67it/s]
# Loading images:  11%|█         | 2/18 [00:00<00:03,  5.17it/s]
# Loading images:  50%|█████     | 9/18 [00:00<00:00, 19.84it/s]
# Loading images: 100%|██████████| 18/18 [00:00<00:00, 24.17it/s]
# Processing activities:  85%|████████▍ | 144/170 [03:49<00:30,  1.19s/it]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:10,  2.50it/s]
# Loading images:  19%|█▊        | 5/27 [00:00<00:02, 10.92it/s]
# Loading images:  33%|███▎      | 9/27 [00:00<00:01, 13.72it/s]
# Loading images:  52%|█████▏    | 14/27 [00:00<00:00, 20.11it/s]
# Loading images: 100%|██████████| 27/27 [00:01<00:00, 17.59it/s]
# Processing activities:  85%|████████▌ | 145/170 [03:51<00:33,  1.32s/it]
# Loading images:   0%|          | 0/54 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/54 [00:00<00:20,  2.59it/s]
# Loading images: 100%|██████████| 54/54 [00:03<00:00, 15.94it/s]
# Processing activities:  86%|████████▌ | 146/170 [03:54<00:48,  2.01s/it]
# Loading images:   0%|          | 0/54 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/54 [00:00<00:35,  1.50it/s]
# Loading images:  24%|██▍       | 13/54 [00:00<00:02, 16.28it/s]
# Loading images:  54%|█████▎    | 29/54 [00:01<00:00, 38.15it/s]
# Loading images:  70%|███████   | 38/54 [00:02<00:01, 14.86it/s]
# Loading images: 100%|██████████| 54/54 [00:02<00:00, 20.43it/s]
# Processing activities:  86%|████████▋ | 147/170 [03:57<00:52,  2.27s/it]
# Loading images:   0%|          | 0/54 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/54 [00:00<00:20,  2.53it/s]
# Loading images: 100%|██████████| 54/54 [00:02<00:00, 20.49it/s]
# Processing activities:  87%|████████▋ | 148/170 [04:00<00:53,  2.45s/it]
# Loading images:   0%|          | 0/36 [00:00<?, ?it/s]
# Loading images:   3%|▎         | 1/36 [00:00<00:13,  2.60it/s]
# Loading images:  31%|███       | 11/36 [00:00<00:00, 26.98it/s]
# Loading images:  44%|████▍     | 16/36 [00:00<00:00, 27.63it/s]
# Loading images:  56%|█████▌    | 20/36 [00:00<00:00, 28.41it/s]
# Loading images:  75%|███████▌  | 27/36 [00:01<00:00, 27.59it/s]
# Loading images: 100%|██████████| 36/36 [00:01<00:00, 22.76it/s]
# Processing activities:  88%|████████▊ | 149/170 [04:02<00:47,  2.26s/it]
# Loading images:   0%|          | 0/36 [00:00<?, ?it/s]
# Loading images:   3%|▎         | 1/36 [00:00<00:12,  2.81it/s]
# Loading images:   8%|▊         | 3/36 [00:00<00:08,  3.74it/s]
# Loading images:  78%|███████▊  | 28/36 [00:00<00:00, 39.90it/s]
# Loading images: 100%|██████████| 36/36 [00:01<00:00, 26.35it/s]
# Processing activities:  88%|████████▊ | 150/170 [04:03<00:40,  2.04s/it]
# Loading images:   0%|          | 0/45 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/45 [00:00<00:09,  4.48it/s]
# Loading images:   4%|▍         | 2/45 [00:00<00:19,  2.15it/s]
# Loading images:  53%|█████▎    | 24/45 [00:01<00:00, 32.27it/s]
# Loading images:  69%|██████▉   | 31/45 [00:01<00:00, 35.69it/s]
# Loading images:  82%|████████▏ | 37/45 [00:01<00:00, 32.66it/s]
# Loading images: 100%|██████████| 45/45 [00:01<00:00, 28.63it/s]
# Processing activities:  89%|████████▉ | 151/170 [04:05<00:37,  1.97s/it]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:04,  5.38it/s]
# Loading images:   7%|▋         | 2/27 [00:00<00:06,  3.76it/s]
# Loading images: 100%|██████████| 27/27 [00:00<00:00, 28.88it/s]
# Processing activities:  89%|████████▉ | 152/170 [04:06<00:30,  1.70s/it]
# Loading images:   0%|          | 0/36 [00:00<?, ?it/s]
# Loading images:   3%|▎         | 1/36 [00:00<00:06,  5.04it/s]
# Loading images:   6%|▌         | 2/36 [00:00<00:06,  5.10it/s]
# Loading images:   8%|▊         | 3/36 [00:00<00:08,  3.79it/s]
# Loading images:  33%|███▎      | 12/36 [00:00<00:01, 19.42it/s]
# Loading images:  64%|██████▍   | 23/36 [00:00<00:00, 36.99it/s]
# Loading images:  81%|████████  | 29/36 [00:01<00:00, 36.97it/s]
# Loading images: 100%|██████████| 36/36 [00:01<00:00, 27.67it/s]
# Processing activities:  90%|█████████ | 153/170 [04:08<00:27,  1.63s/it]
# Loading images:   0%|          | 0/54 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/54 [00:00<00:30,  1.73it/s]
# Loading images:  17%|█▋        | 9/54 [00:00<00:03, 13.55it/s]
# Loading images:  43%|████▎     | 23/54 [00:00<00:00, 32.06it/s]
# Loading images:  52%|█████▏    | 28/54 [00:01<00:00, 29.42it/s]
# Loading images:  59%|█████▉    | 32/54 [00:01<00:00, 29.77it/s]
# Loading images:  72%|███████▏  | 39/54 [00:01<00:00, 37.32it/s]
# Loading images:  81%|████████▏ | 44/54 [00:01<00:00, 33.20it/s]
# Loading images:  91%|█████████ | 49/54 [00:01<00:00, 34.97it/s]
# Loading images: 100%|██████████| 54/54 [00:01<00:00, 29.06it/s]
# Processing activities:  91%|█████████ | 154/170 [04:10<00:28,  1.77s/it]
# Loading images:   0%|          | 0/36 [00:00<?, ?it/s]
# Loading images:   3%|▎         | 1/36 [00:00<00:14,  2.34it/s]
# Loading images:  36%|███▌      | 13/36 [00:00<00:00, 25.97it/s]
# Loading images:  47%|████▋     | 17/36 [00:00<00:00, 23.07it/s]
# Loading images:  75%|███████▌  | 27/36 [00:00<00:00, 36.43it/s]
# Loading images: 100%|██████████| 36/36 [00:01<00:00, 29.25it/s]
# Processing activities:  91%|█████████ | 155/170 [04:11<00:24,  1.67s/it]
# Loading images:   0%|          | 0/27 [00:00<?, ?it/s]
# Loading images:   4%|▎         | 1/27 [00:00<00:12,  2.10it/s]
# Loading images:  52%|█████▏    | 14/27 [00:00<00:00, 29.91it/s]
# Loading images:  78%|███████▊  | 21/27 [00:01<00:00, 23.05it/s]
# Loading images: 100%|██████████| 27/27 [00:01<00:00, 21.47it/s]
# Processing activities:  92%|█████████▏| 156/170 [04:13<00:22,  1.58s/it]
# Loading images:   0%|          | 0/45 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/45 [00:00<00:09,  4.71it/s]
# Loading images:   7%|▋         | 3/45 [00:00<00:05,  7.30it/s]
# Loading images:  33%|███▎      | 15/45 [00:00<00:01, 29.88it/s]
# Loading images:  42%|████▏     | 19/45 [00:00<00:00, 28.96it/s]
# Loading images:  49%|████▉     | 22/45 [00:01<00:01, 18.26it/s]
# Loading images:  64%|██████▍   | 29/45 [00:01<00:00, 22.66it/s]
# Loading images: 100%|██████████| 45/45 [00:01<00:00, 29.43it/s]
# Processing activities:  92%|█████████▏| 157/170 [04:14<00:21,  1.64s/it]
# Loading images:   0%|          | 0/45 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/45 [00:00<00:21,  2.07it/s]
# Loading images:  31%|███       | 14/45 [00:00<00:01, 26.07it/s]
# Loading images:  42%|████▏     | 19/45 [00:00<00:01, 25.28it/s]
# Loading images:  62%|██████▏   | 28/45 [00:01<00:00, 31.92it/s]
# Loading images:  71%|███████   | 32/45 [00:01<00:00, 21.30it/s]
# Loading images: 100%|██████████| 45/45 [00:01<00:00, 26.29it/s]
# Processing activities:  93%|█████████▎| 158/170 [04:16<00:20,  1.72s/it]
# Loading images:   0%|          | 0/36 [00:00<?, ?it/s]
# Loading images:   3%|▎         | 1/36 [00:00<00:14,  2.43it/s]
# Loading images:  11%|█         | 4/36 [00:00<00:05,  5.77it/s]
# Loading images:  14%|█▍        | 5/36 [00:02<00:18,  1.67it/s]
# Loading images: 100%|██████████| 36/36 [00:03<00:00,  9.48it/s]
# Processing activities:  94%|█████████▎| 159/170 [04:20<00:26,  2.40s/it]
# Loading images:   0%|          | 0/36 [00:00<?, ?it/s]
# Loading images:   3%|▎         | 1/36 [00:00<00:11,  3.15it/s]
# Loading images:  33%|███▎      | 12/36 [00:00<00:00, 35.54it/s]
# Loading images:  53%|█████▎    | 19/36 [00:00<00:00, 25.23it/s]
# Loading images:  67%|██████▋   | 24/36 [00:01<00:00, 24.39it/s]
# Loading images: 100%|██████████| 36/36 [00:01<00:00, 19.15it/s]
# Processing activities:  94%|█████████▍| 160/170 [04:22<00:22,  2.30s/it]
# Loading images:   0%|          | 0/54 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/54 [00:00<00:22,  2.32it/s]
# Loading images:  26%|██▌       | 14/54 [00:00<00:01, 21.19it/s]
# Loading images:  43%|████▎     | 23/54 [00:00<00:00, 33.53it/s]
# Loading images:  54%|█████▎    | 29/54 [00:01<00:00, 27.89it/s]
# Loading images:  63%|██████▎   | 34/54 [00:01<00:00, 31.31it/s]
# Loading images:  72%|███████▏  | 39/54 [00:01<00:00, 25.52it/s]
# Loading images:  83%|████████▎ | 45/54 [00:01<00:00, 28.42it/s]
# Loading images: 100%|██████████| 54/54 [00:01<00:00, 28.36it/s]
# Processing activities:  95%|█████████▍| 161/170 [04:25<00:20,  2.27s/it]
# Loading images:   0%|          | 0/45 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/45 [00:00<00:18,  2.44it/s]
# Loading images:  16%|█▌        | 7/45 [00:00<00:02, 14.05it/s]
# Loading images:  40%|████      | 18/45 [00:00<00:01, 23.74it/s]
# Loading images:  64%|██████▍   | 29/45 [00:01<00:00, 36.70it/s]
# Loading images:  76%|███████▌  | 34/45 [00:01<00:00, 32.87it/s]
# Loading images:  84%|████████▍ | 38/45 [00:01<00:00, 31.02it/s]
# Loading images: 100%|██████████| 45/45 [00:01<00:00, 27.79it/s]
# Processing activities:  95%|█████████▌| 162/170 [04:26<00:17,  2.14s/it]
# Loading images:   0%|          | 0/45 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/45 [00:00<00:09,  4.44it/s]
# Loading images:  11%|█         | 5/45 [00:00<00:02, 18.04it/s]
# Loading images:  27%|██▋       | 12/45 [00:00<00:01, 32.69it/s]
# Loading images:  36%|███▌      | 16/45 [00:00<00:01, 16.54it/s]
# Loading images:  64%|██████▍   | 29/45 [00:01<00:00, 34.08it/s]
# Loading images:  78%|███████▊  | 35/45 [00:01<00:00, 34.45it/s]
# Loading images:  89%|████████▉ | 40/45 [00:01<00:00, 35.84it/s]
# Loading images: 100%|██████████| 45/45 [00:01<00:00, 30.66it/s]
# Processing activities:  96%|█████████▌| 163/170 [04:28<00:13,  2.00s/it]
# Loading images:   0%|          | 0/36 [00:00<?, ?it/s]
# Loading images:   3%|▎         | 1/36 [00:00<00:13,  2.52it/s]
# Loading images:  25%|██▌       | 9/36 [00:00<00:01, 22.98it/s]
# Loading images:  39%|███▉      | 14/36 [00:00<00:00, 23.09it/s]
# Loading images:  53%|█████▎    | 19/36 [00:00<00:00, 21.65it/s]
# Loading images:  81%|████████  | 29/36 [00:01<00:00, 35.33it/s]
# Loading images: 100%|██████████| 36/36 [00:01<00:00, 27.70it/s]
# Processing activities:  96%|█████████▋| 164/170 [04:30<00:11,  1.85s/it]
# Loading images:   0%|          | 0/45 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/45 [00:00<00:13,  3.28it/s]
# Loading images:   4%|▍         | 2/45 [00:00<00:11,  3.66it/s]
# Loading images:  31%|███       | 14/45 [00:00<00:01, 24.67it/s]
# Loading images:  51%|█████     | 23/45 [00:00<00:00, 31.54it/s]
# Loading images:  60%|██████    | 27/45 [00:01<00:00, 21.78it/s]
# Loading images: 100%|██████████| 45/45 [00:01<00:00, 29.43it/s]
# Processing activities:  97%|█████████▋| 165/170 [04:31<00:09,  1.82s/it]
# Loading images:   0%|          | 0/36 [00:00<?, ?it/s]
# Loading images:   3%|▎         | 1/36 [00:00<00:11,  2.98it/s]
# Loading images:  19%|█▉        | 7/36 [00:00<00:01, 17.64it/s]
# Loading images:  36%|███▌      | 13/36 [00:00<00:01, 19.77it/s]
# Loading images:  53%|█████▎    | 19/36 [00:00<00:00, 24.25it/s]
# Loading images:  72%|███████▏  | 26/36 [00:01<00:00, 31.00it/s]
# Loading images: 100%|██████████| 36/36 [00:01<00:00, 28.26it/s]
# Processing activities:  98%|█████████▊| 166/170 [04:33<00:06,  1.70s/it]
# Loading images:   0%|          | 0/36 [00:00<?, ?it/s]
# Loading images:   3%|▎         | 1/36 [00:00<00:13,  2.52it/s]
# Loading images:  36%|███▌      | 13/36 [00:00<00:00, 25.07it/s]
# Loading images:  53%|█████▎    | 19/36 [00:00<00:00, 31.89it/s]
# Loading images:  67%|██████▋   | 24/36 [00:00<00:00, 29.38it/s]
# Loading images:  78%|███████▊  | 28/36 [00:01<00:00, 27.74it/s]
# Loading images:  89%|████████▉ | 32/36 [00:01<00:00, 28.69it/s]
# Loading images: 100%|██████████| 36/36 [00:01<00:00, 25.71it/s]
# Processing activities:  98%|█████████▊| 167/170 [04:34<00:04,  1.66s/it]
# Loading images:   0%|          | 0/45 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/45 [00:00<00:17,  2.55it/s]
# Loading images:  13%|█▎        | 6/45 [00:00<00:03, 10.15it/s]
# Loading images:  18%|█▊        | 8/45 [00:00<00:04,  8.63it/s]
# Loading images:  49%|████▉     | 22/45 [00:01<00:00, 23.90it/s]
# Loading images:  64%|██████▍   | 29/45 [00:01<00:00, 29.71it/s]
# Loading images:  78%|███████▊  | 35/45 [00:01<00:00, 33.48it/s]
# Loading images:  87%|████████▋ | 39/45 [00:01<00:00, 29.32it/s]
# Loading images: 100%|██████████| 45/45 [00:01<00:00, 23.27it/s]
# Processing activities:  99%|█████████▉| 168/170 [04:36<00:03,  1.81s/it]
# Loading images:   0%|          | 0/45 [00:00<?, ?it/s]
# Loading images:   2%|▏         | 1/45 [00:00<00:17,  2.52it/s]
# Loading images:   7%|▋         | 3/45 [00:00<00:06,  6.30it/s]
# Loading images:  11%|█         | 5/45 [00:01<00:14,  2.81it/s]
# Loading images: 100%|██████████| 45/45 [00:01<00:00, 23.64it/s]
# Processing activities:  99%|█████████▉| 169/170 [04:39<00:01,  1.90s/it]
# Loading images:   0%|          | 0/36 [00:00<?, ?it/s]
# Loading images:   3%|▎         | 1/36 [00:00<00:11,  2.98it/s]
# Loading images: 100%|██████████| 36/36 [00:01<00:00, 26.77it/s]
# Processing activities: 100%|██████████| 170/170 [04:40<00:00,  1.65s/it]

# %%
import numpy as np

file_path = f"/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_{version_number}/videos/processed-npy-files/Subject17Activity5Trial2Camera1/window_001.npy"
file_path2 = '/content/drive/MyDrive/Fall-Detection/UP-Fall-Dataset/processed_optical_flow_downsampled/Subject1/Activity1/Trial1/Subject1Activity1Trial1Camera1_2018-07-04T12_04_20.238369.npy'
data = np.load(file_path2, allow_pickle=True)

print("Type:", type(data))
print("Shape:", data.shape)
print("Data (sample):", data)
# Out:
# Type: <class 'numpy.ndarray'>
# Shape: ()
# Data (sample): {'array': array([[[[-1.94790671e-04,  2.31926490e-04],
#          [ 3.24738026e-03,  5.57897729e-04],
#          [ 8.27530585e-03, -1.71335111e-03],
#          ...,
#          [-5.07842749e-03, -3.35421087e-03],
#          [-2.95825594e-04,  3.11465905e-04],
#          [-1.02672260e-02,  2.42669648e-03]],
#
#         [[ 1.41017523e-03, -9.88822803e-03],
#          [ 5.30477129e-02,  4.57581729e-02],
#          [ 1.92894635e-03,  1.64441823e-03],
#          ...,
#          [-3.32166217e-02, -7.40260864e-03],
#          [ 1.69735332e-03,  1.64632313e-03],
#          [-1.78066120e-02,  7.44126132e-03]],
#
#         [[-2.37303018e-03, -5.34857437e-03],
#          [ 1.17886737e-02,  1.30031956e-02],
#          [-2.24370218e-04, -1.36472296e-03],
#          ...,
#          [-1.73691101e-02, -2.46265437e-03],
#          [ 1.32828124e-03, -1.50199502e-03],
#          [ 6.58163044e-04,  1.10976142e-03]],
#
#         ...,
#
#         [[-3.87202716e-04, -2.48549826e-04],
#          [-9.26615146e-04, -5.67352748e-04],
#          [ 5.54809486e-03,  2.10686773e-02],
#          ...,
#          [ 4.95268544e-03, -7.75537686e-03],
#          [-2.52319267e-03, -5.47897536e-03],
#          [-1.23219313e-02,  1.55175505e-02]],
#
#         [[ 5.41528454e-03, -1.95761323e-02],
#          [-2.08206493e-02, -5.28283592e-04],
#          [ 5.61282970e-03,  1.17054190e-02],
#          ...,
#          [ 2.59546540e-03, -1.35403527e-02],
#          [ 1.13587943e-03,  5.00300433e-04],
#          [-5.22428891e-03,  1.11681446e-02]],
#
#         [[ 1.38396421e-03, -1.09889461e-02],
#          [-3.26150469e-03,  1.66604598e-03],
#          [ 3.18872719e-03,  3.33785056e-03],
#          ...,
#          [ 2.12402130e-03, -4.69975872e-03],
#          [-4.61477507e-03,  2.28877598e-03],
#          [ 8.75801779e-03,  3.77188250e-03]]],
#
#
#        [[[ 2.89314630e-04, -1.15834747e-03],
#          [-3.17877787e-03,  2.71413848e-03],
#          [ 7.10839266e-03, -2.31014914e-03],
#          ...,
#          [ 2.27084546e-03,  2.22480670e-03],
#          [ 5.39590605e-03, -2.98682530e-03],
#          [-3.47543578e-03,  2.26326799e-03]],
#
#         [[-3.57120996e-03, -4.95749759e-04],
#          [ 1.32328952e-02,  7.31778843e-03],
#          [ 1.04820505e-02, -2.21680780e-03],
#          ...,
#          [ 1.56486116e-03,  1.01394681e-02],
#          [ 2.55287997e-03, -6.32106513e-03],
#          [-7.29942415e-03,  3.01811378e-03]],
#
#         [[-3.37703759e-03,  1.06335292e-03],
#          [ 9.88622196e-03,  2.16603070e-03],
#          [-1.63953390e-03, -3.72379669e-03],
#          ...,
#          [-7.65745854e-03,  6.53640600e-03],
#          [ 1.59267744e-03, -5.13346493e-03],
#          [-1.01112749e-03,  6.59255020e-04]],
#
#         ...,
#
#         [[ 1.88478455e-03,  2.23482784e-04],
#          [ 1.73392904e-03, -2.33878987e-03],
#          [-1.37827443e-02,  6.90449233e-05],
#          ...,
#          [-5.62407868e-03,  1.64890441e-03],
#          [ 3.38350167e-03, -8.44907388e-03],
#          [ 2.82255281e-02,  8.15326814e-03]],
#
#         [[ 1.45219415e-02, -1.18952161e-02],
#          [ 3.04579232e-02, -3.48054990e-02],
#          [ 7.44406367e-03,  3.95566225e-03],
#          ...,
#          [-2.23869388e-03,  1.70499936e-03],
#          [ 2.30249716e-05, -1.11022843e-02],
#          [-8.92798323e-03, -3.90567211e-03]],
#
#         [[ 9.53729451e-03, -9.89224110e-03],
#          [ 2.53226720e-02, -2.03516576e-02],
#          [-2.58115539e-03,  4.69050603e-03],
#          ...,
#          [ 4.66381578e-04, -6.50925678e-04],
#          [-3.64968716e-03, -2.48811510e-03],
#          [-1.24605475e-02, -4.70748357e-03]]],
#
#
#        [[[-2.21712468e-03,  1.61534568e-04],
#          [ 2.42621568e-03, -2.99082790e-03],
#          [-1.38507248e-03,  3.65465158e-03],
#          ...,
#          [-1.96396513e-03, -6.57494040e-03],
#          [-1.64262224e-02,  1.40731996e-02],
#          [ 4.08641342e-03, -2.67174793e-04]],
#
#         [[-3.83681827e-03, -8.87569448e-04],
#          [-1.43650556e-02, -2.91174855e-02],
#          [ 2.68296804e-02,  1.21422019e-02],
#          ...,
#          [ 8.79147905e-04, -2.00883411e-02],
#          [-2.33552586e-02,  2.42503136e-02],
#          [ 1.12701561e-02, -1.14065444e-03]],
#
#         [[ 1.91401690e-04,  1.44754280e-03],
#          [-9.15147737e-03, -5.89358248e-03],
#          [ 5.41767245e-03,  7.84877315e-03],
#          ...,
#          [-9.91530134e-04, -1.21110091e-02],
#          [-8.28191231e-04, -1.49711501e-03],
#          [-5.35198604e-04,  9.32323164e-04]],
#
#         ...,
#
#         [[ 7.23141857e-05, -2.84584099e-03],
#          [ 1.63060694e-03, -2.76256796e-05],
#          [ 1.54111283e-02,  3.65504296e-03],
#          ...,
#          [ 1.23276571e-02, -1.86620734e-03],
#          [-2.05238964e-02,  1.07455729e-02],
#          [-1.20594996e-04,  4.31716070e-03]],
#
#         [[-1.10478187e-02, -1.14166259e-03],
#          [-1.82028802e-03, -1.10043222e-02],
#          [ 6.50199922e-03, -3.44907865e-02],
#          ...,
#          [ 8.97012744e-03,  4.78907814e-03],
#          [-1.97890904e-02,  2.03530341e-02],
#          [ 5.43764234e-03,  1.03534032e-02]],
#
#         [[-7.01681664e-03, -3.96706490e-03],
#          [-1.45246228e-03, -1.02044223e-02],
#          [ 1.92347099e-03,  7.69592822e-04],
#          ...,
#          [ 2.22845678e-03,  3.62621574e-03],
#          [-3.14110564e-03,  4.84438986e-03],
#          [ 1.78997521e-03, -2.38411405e-04]]],
#
#
#        ...,
#
#
#        [[[ 1.35494251e-04, -2.69436314e-05],
#          [ 1.72976078e-03, -5.19029272e-04],
#          [-3.65456101e-03,  8.15019105e-03],
#          ...,
#          [ 3.95900663e-03, -2.82628322e-03],
#          [ 6.18579681e-04, -9.52192768e-03],
#          [ 3.87285044e-03, -3.36215226e-03]],
#
#         [[-2.22996576e-03, -4.11051093e-03],
#          [ 2.90383492e-03, -9.33379401e-04],
#          [-5.13059180e-03,  8.76213983e-03],
#          ...,
#          [ 1.66265375e-03, -6.09487947e-03],
#          [ 1.62136666e-02, -1.86129529e-02],
#          [ 5.45989629e-03, -1.30059766e-02]],
#
#         [[-6.44717074e-04, -4.12325328e-03],
#          [ 1.69817335e-03, -3.58658051e-03],
#          [ 2.33468163e-04,  6.07366848e-04],
#          ...,
#          [-3.39365713e-02, -3.88791785e-02],
#          [-1.20816310e-03,  1.10097078e-03],
#          [-1.91750668e-03, -2.45043845e-03]],
#
#         ...,
#
#         [[ 2.33009644e-03,  9.62194637e-04],
#          [ 2.00940140e-05, -7.01133104e-05],
#          [-1.04531385e-02,  1.55855352e-02],
#          ...,
#          [ 5.10096317e-04,  1.38130412e-03],
#          [-1.69275259e-03,  5.51041798e-04],
#          [ 7.82269170e-04,  1.25584484e-03]],
#
#         [[ 1.08859865e-02,  1.57954881e-03],
#          [-8.75254720e-03,  4.64975229e-03],
#          [-3.20416875e-03,  2.25706436e-02],
#          ...,
#          [-1.13714002e-02, -1.34611549e-03],
#          [ 1.69942214e-04,  2.87215895e-04],
#          [-3.15095251e-03,  1.68018136e-02]],
#
#         [[ 6.14729337e-03,  1.83943054e-03],
#          [ 1.83908863e-03,  4.84409463e-03],
#          [-4.88582184e-04,  3.46606737e-03],
#          ...,
#          [-3.21558258e-03, -2.61354260e-03],
#          [-5.39497589e-04, -7.46885664e-04],
#          [ 3.80500453e-04,  6.95451768e-03]]],
#
#
#        [[[-2.15565906e-05,  1.35053502e-04],
#          [ 1.11734332e-03, -4.45634709e-04],
#          [-1.73653977e-03,  2.98235728e-03],
#          ...,
#          [-3.61092010e-04,  1.93573209e-03],
#          [ 1.69089139e-02,  4.86945501e-03],
#          [-2.80736969e-03,  3.84995074e-04]],
#
#         [[-1.03808446e-02, -2.63383263e-03],
#          [ 2.05096416e-03,  3.57657060e-04],
#          [-6.56432146e-03,  5.82957920e-03],
#          ...,
#          [ 6.51798910e-04, -1.24005630e-04],
#          [ 1.94960386e-02,  7.89907202e-03],
#          [-7.26303598e-03,  2.86018988e-03]],
#
#         [[-3.01438756e-03, -4.72101878e-04],
#          [-3.17404163e-03, -9.35333956e-04],
#          [-1.45026320e-03,  3.73503496e-03],
#          ...,
#          [ 1.00916289e-02, -1.74757335e-02],
#          [-2.41657416e-03,  1.00596680e-03],
#          [-2.31427676e-03, -2.09372910e-03]],
#
#         ...,
#
#         [[ 1.48038601e-03,  4.21788252e-04],
#          [-2.26838537e-03,  2.46385043e-03],
#          [ 2.65184487e-03,  8.83602351e-03],
#          ...,
#          [ 9.56100691e-03, -5.36558917e-03],
#          [ 4.68761986e-03, -3.19687603e-03],
#          [-9.61702724e-04,  2.55526509e-03]],
#
#         [[-4.01517004e-03, -1.27370551e-03],
#          [ 7.93096516e-03,  2.06375867e-03],
#          [-4.54312330e-03,  7.25538749e-03],
#          ...,
#          [ 8.86354689e-03, -5.91332559e-03],
#          [ 1.04962559e-02,  5.53296693e-03],
#          [ 2.32825615e-03,  7.38974102e-03]],
#
#         [[-6.59757480e-03, -6.21451531e-03],
#          [ 9.27527342e-03, -5.56116179e-03],
#          [ 7.09342887e-04,  7.97691115e-04],
#          ...,
#          [-1.34978502e-03, -1.10548013e-03],
#          [ 3.25968256e-04,  5.33975102e-03],
#          [ 2.15231883e-03,  3.89143988e-03]]],
#
#
#        [[[-8.73918063e-04,  6.46298926e-04],
#          [ 8.12051294e-04,  2.68806092e-04],
#          [ 1.16735399e-02,  5.72246965e-03],
#          ...,
#          [ 2.15555634e-03, -2.02599076e-05],
#          [-1.14459489e-02, -1.10288698e-03],
#          [ 3.85637861e-03, -4.41956072e-04]],
#
#         [[-4.33047768e-03,  6.35588868e-03],
#          [-3.00543034e-04,  1.20795257e-02],
#          [ 1.71131771e-02,  1.49615286e-02],
#          ...,
#          [ 1.32448496e-02, -5.13690989e-03],
#          [-1.36897638e-02,  3.36464006e-03],
#          [ 5.66754676e-03,  2.48845201e-03]],
#
#         [[-4.14542519e-05,  2.47704750e-03],
#          [ 1.97252911e-03,  2.01938860e-03],
#          [-1.29256854e-02, -1.23228133e-03],
#          ...,
#          [ 1.36225935e-04, -1.08958520e-02],
#          [ 1.27928983e-03,  2.70231813e-03],
#          [-9.60989099e-04,  9.26267880e-04]],
#
#         ...,
#
#         [[-1.06960841e-04,  1.46880664e-03],
#          [-1.04797317e-03,  6.33276475e-04],
#          [ 1.91761553e-02,  1.16308201e-02],
#          ...,
#          [-1.08447550e-02, -6.66657696e-03],
#          [-3.33750364e-03,  3.80416727e-03],
#          [-2.58930004e-03, -3.49426130e-03]],
#
#         [[-8.77886731e-03, -5.68693643e-03],
#          [-1.99718345e-02,  2.80686910e-03],
#          [ 2.47826036e-02,  1.44943101e-02],
#          ...,
#          [-1.88772772e-02, -1.37328161e-02],
#          [ 2.87372665e-03,  1.88265592e-02],
#          [-1.40148755e-02, -4.23732866e-03]],
#
#         [[-1.23004727e-02, -3.47546767e-03],
#          [-1.84228737e-02,  3.28457053e-03],
#          [ 3.17206606e-03,  2.73630302e-03],
#          ...,
#          [ 1.34935207e-03, -2.85290927e-03],
#          [-6.33492228e-03,  4.32708208e-03],
#          [-3.90029582e-03, -2.61352491e-03]]]], dtype=float32), 'label': np.int64(1)}

# %%
import numpy as np

file_path = f"/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_{version_number}/videos/processed-npy-files-v2/Subject5Activity1Trial1Camera1/window_002.npy"
file_path2 = '/content/drive/MyDrive/Fall-Detection/UP-Fall-Dataset/processed_optical_flow_downsampled/Subject1/Activity1/Trial1/Subject1Activity1Trial1Camera1_2018-07-04T12_04_20.238369.npy'
data = np.load(file_path2, allow_pickle=True)

print("Type:", type(data))
print("Shape:", data.shape)
print("Data (sample):", data)
# Out:
# Type: <class 'numpy.ndarray'>
# Shape: ()
# Data (sample): {'array': array([[[[-1.94790671e-04,  2.31926490e-04],
#          [ 3.24738026e-03,  5.57897729e-04],
#          [ 8.27530585e-03, -1.71335111e-03],
#          ...,
#          [-5.07842749e-03, -3.35421087e-03],
#          [-2.95825594e-04,  3.11465905e-04],
#          [-1.02672260e-02,  2.42669648e-03]],
#
#         [[ 1.41017523e-03, -9.88822803e-03],
#          [ 5.30477129e-02,  4.57581729e-02],
#          [ 1.92894635e-03,  1.64441823e-03],
#          ...,
#          [-3.32166217e-02, -7.40260864e-03],
#          [ 1.69735332e-03,  1.64632313e-03],
#          [-1.78066120e-02,  7.44126132e-03]],
#
#         [[-2.37303018e-03, -5.34857437e-03],
#          [ 1.17886737e-02,  1.30031956e-02],
#          [-2.24370218e-04, -1.36472296e-03],
#          ...,
#          [-1.73691101e-02, -2.46265437e-03],
#          [ 1.32828124e-03, -1.50199502e-03],
#          [ 6.58163044e-04,  1.10976142e-03]],
#
#         ...,
#
#         [[-3.87202716e-04, -2.48549826e-04],
#          [-9.26615146e-04, -5.67352748e-04],
#          [ 5.54809486e-03,  2.10686773e-02],
#          ...,
#          [ 4.95268544e-03, -7.75537686e-03],
#          [-2.52319267e-03, -5.47897536e-03],
#          [-1.23219313e-02,  1.55175505e-02]],
#
#         [[ 5.41528454e-03, -1.95761323e-02],
#          [-2.08206493e-02, -5.28283592e-04],
#          [ 5.61282970e-03,  1.17054190e-02],
#          ...,
#          [ 2.59546540e-03, -1.35403527e-02],
#          [ 1.13587943e-03,  5.00300433e-04],
#          [-5.22428891e-03,  1.11681446e-02]],
#
#         [[ 1.38396421e-03, -1.09889461e-02],
#          [-3.26150469e-03,  1.66604598e-03],
#          [ 3.18872719e-03,  3.33785056e-03],
#          ...,
#          [ 2.12402130e-03, -4.69975872e-03],
#          [-4.61477507e-03,  2.28877598e-03],
#          [ 8.75801779e-03,  3.77188250e-03]]],
#
#
#        [[[ 2.89314630e-04, -1.15834747e-03],
#          [-3.17877787e-03,  2.71413848e-03],
#          [ 7.10839266e-03, -2.31014914e-03],
#          ...,
#          [ 2.27084546e-03,  2.22480670e-03],
#          [ 5.39590605e-03, -2.98682530e-03],
#          [-3.47543578e-03,  2.26326799e-03]],
#
#         [[-3.57120996e-03, -4.95749759e-04],
#          [ 1.32328952e-02,  7.31778843e-03],
#          [ 1.04820505e-02, -2.21680780e-03],
#          ...,
#          [ 1.56486116e-03,  1.01394681e-02],
#          [ 2.55287997e-03, -6.32106513e-03],
#          [-7.29942415e-03,  3.01811378e-03]],
#
#         [[-3.37703759e-03,  1.06335292e-03],
#          [ 9.88622196e-03,  2.16603070e-03],
#          [-1.63953390e-03, -3.72379669e-03],
#          ...,
#          [-7.65745854e-03,  6.53640600e-03],
#          [ 1.59267744e-03, -5.13346493e-03],
#          [-1.01112749e-03,  6.59255020e-04]],
#
#         ...,
#
#         [[ 1.88478455e-03,  2.23482784e-04],
#          [ 1.73392904e-03, -2.33878987e-03],
#          [-1.37827443e-02,  6.90449233e-05],
#          ...,
#          [-5.62407868e-03,  1.64890441e-03],
#          [ 3.38350167e-03, -8.44907388e-03],
#          [ 2.82255281e-02,  8.15326814e-03]],
#
#         [[ 1.45219415e-02, -1.18952161e-02],
#          [ 3.04579232e-02, -3.48054990e-02],
#          [ 7.44406367e-03,  3.95566225e-03],
#          ...,
#          [-2.23869388e-03,  1.70499936e-03],
#          [ 2.30249716e-05, -1.11022843e-02],
#          [-8.92798323e-03, -3.90567211e-03]],
#
#         [[ 9.53729451e-03, -9.89224110e-03],
#          [ 2.53226720e-02, -2.03516576e-02],
#          [-2.58115539e-03,  4.69050603e-03],
#          ...,
#          [ 4.66381578e-04, -6.50925678e-04],
#          [-3.64968716e-03, -2.48811510e-03],
#          [-1.24605475e-02, -4.70748357e-03]]],
#
#
#        [[[-2.21712468e-03,  1.61534568e-04],
#          [ 2.42621568e-03, -2.99082790e-03],
#          [-1.38507248e-03,  3.65465158e-03],
#          ...,
#          [-1.96396513e-03, -6.57494040e-03],
#          [-1.64262224e-02,  1.40731996e-02],
#          [ 4.08641342e-03, -2.67174793e-04]],
#
#         [[-3.83681827e-03, -8.87569448e-04],
#          [-1.43650556e-02, -2.91174855e-02],
#          [ 2.68296804e-02,  1.21422019e-02],
#          ...,
#          [ 8.79147905e-04, -2.00883411e-02],
#          [-2.33552586e-02,  2.42503136e-02],
#          [ 1.12701561e-02, -1.14065444e-03]],
#
#         [[ 1.91401690e-04,  1.44754280e-03],
#          [-9.15147737e-03, -5.89358248e-03],
#          [ 5.41767245e-03,  7.84877315e-03],
#          ...,
#          [-9.91530134e-04, -1.21110091e-02],
#          [-8.28191231e-04, -1.49711501e-03],
#          [-5.35198604e-04,  9.32323164e-04]],
#
#         ...,
#
#         [[ 7.23141857e-05, -2.84584099e-03],
#          [ 1.63060694e-03, -2.76256796e-05],
#          [ 1.54111283e-02,  3.65504296e-03],
#          ...,
#          [ 1.23276571e-02, -1.86620734e-03],
#          [-2.05238964e-02,  1.07455729e-02],
#          [-1.20594996e-04,  4.31716070e-03]],
#
#         [[-1.10478187e-02, -1.14166259e-03],
#          [-1.82028802e-03, -1.10043222e-02],
#          [ 6.50199922e-03, -3.44907865e-02],
#          ...,
#          [ 8.97012744e-03,  4.78907814e-03],
#          [-1.97890904e-02,  2.03530341e-02],
#          [ 5.43764234e-03,  1.03534032e-02]],
#
#         [[-7.01681664e-03, -3.96706490e-03],
#          [-1.45246228e-03, -1.02044223e-02],
#          [ 1.92347099e-03,  7.69592822e-04],
#          ...,
#          [ 2.22845678e-03,  3.62621574e-03],
#          [-3.14110564e-03,  4.84438986e-03],
#          [ 1.78997521e-03, -2.38411405e-04]]],
#
#
#        ...,
#
#
#        [[[ 1.35494251e-04, -2.69436314e-05],
#          [ 1.72976078e-03, -5.19029272e-04],
#          [-3.65456101e-03,  8.15019105e-03],
#          ...,
#          [ 3.95900663e-03, -2.82628322e-03],
#          [ 6.18579681e-04, -9.52192768e-03],
#          [ 3.87285044e-03, -3.36215226e-03]],
#
#         [[-2.22996576e-03, -4.11051093e-03],
#          [ 2.90383492e-03, -9.33379401e-04],
#          [-5.13059180e-03,  8.76213983e-03],
#          ...,
#          [ 1.66265375e-03, -6.09487947e-03],
#          [ 1.62136666e-02, -1.86129529e-02],
#          [ 5.45989629e-03, -1.30059766e-02]],
#
#         [[-6.44717074e-04, -4.12325328e-03],
#          [ 1.69817335e-03, -3.58658051e-03],
#          [ 2.33468163e-04,  6.07366848e-04],
#          ...,
#          [-3.39365713e-02, -3.88791785e-02],
#          [-1.20816310e-03,  1.10097078e-03],
#          [-1.91750668e-03, -2.45043845e-03]],
#
#         ...,
#
#         [[ 2.33009644e-03,  9.62194637e-04],
#          [ 2.00940140e-05, -7.01133104e-05],
#          [-1.04531385e-02,  1.55855352e-02],
#          ...,
#          [ 5.10096317e-04,  1.38130412e-03],
#          [-1.69275259e-03,  5.51041798e-04],
#          [ 7.82269170e-04,  1.25584484e-03]],
#
#         [[ 1.08859865e-02,  1.57954881e-03],
#          [-8.75254720e-03,  4.64975229e-03],
#          [-3.20416875e-03,  2.25706436e-02],
#          ...,
#          [-1.13714002e-02, -1.34611549e-03],
#          [ 1.69942214e-04,  2.87215895e-04],
#          [-3.15095251e-03,  1.68018136e-02]],
#
#         [[ 6.14729337e-03,  1.83943054e-03],
#          [ 1.83908863e-03,  4.84409463e-03],
#          [-4.88582184e-04,  3.46606737e-03],
#          ...,
#          [-3.21558258e-03, -2.61354260e-03],
#          [-5.39497589e-04, -7.46885664e-04],
#          [ 3.80500453e-04,  6.95451768e-03]]],
#
#
#        [[[-2.15565906e-05,  1.35053502e-04],
#          [ 1.11734332e-03, -4.45634709e-04],
#          [-1.73653977e-03,  2.98235728e-03],
#          ...,
#          [-3.61092010e-04,  1.93573209e-03],
#          [ 1.69089139e-02,  4.86945501e-03],
#          [-2.80736969e-03,  3.84995074e-04]],
#
#         [[-1.03808446e-02, -2.63383263e-03],
#          [ 2.05096416e-03,  3.57657060e-04],
#          [-6.56432146e-03,  5.82957920e-03],
#          ...,
#          [ 6.51798910e-04, -1.24005630e-04],
#          [ 1.94960386e-02,  7.89907202e-03],
#          [-7.26303598e-03,  2.86018988e-03]],
#
#         [[-3.01438756e-03, -4.72101878e-04],
#          [-3.17404163e-03, -9.35333956e-04],
#          [-1.45026320e-03,  3.73503496e-03],
#          ...,
#          [ 1.00916289e-02, -1.74757335e-02],
#          [-2.41657416e-03,  1.00596680e-03],
#          [-2.31427676e-03, -2.09372910e-03]],
#
#         ...,
#
#         [[ 1.48038601e-03,  4.21788252e-04],
#          [-2.26838537e-03,  2.46385043e-03],
#          [ 2.65184487e-03,  8.83602351e-03],
#          ...,
#          [ 9.56100691e-03, -5.36558917e-03],
#          [ 4.68761986e-03, -3.19687603e-03],
#          [-9.61702724e-04,  2.55526509e-03]],
#
#         [[-4.01517004e-03, -1.27370551e-03],
#          [ 7.93096516e-03,  2.06375867e-03],
#          [-4.54312330e-03,  7.25538749e-03],
#          ...,
#          [ 8.86354689e-03, -5.91332559e-03],
#          [ 1.04962559e-02,  5.53296693e-03],
#          [ 2.32825615e-03,  7.38974102e-03]],
#
#         [[-6.59757480e-03, -6.21451531e-03],
#          [ 9.27527342e-03, -5.56116179e-03],
#          [ 7.09342887e-04,  7.97691115e-04],
#          ...,
#          [-1.34978502e-03, -1.10548013e-03],
#          [ 3.25968256e-04,  5.33975102e-03],
#          [ 2.15231883e-03,  3.89143988e-03]]],
#
#
#        [[[-8.73918063e-04,  6.46298926e-04],
#          [ 8.12051294e-04,  2.68806092e-04],
#          [ 1.16735399e-02,  5.72246965e-03],
#          ...,
#          [ 2.15555634e-03, -2.02599076e-05],
#          [-1.14459489e-02, -1.10288698e-03],
#          [ 3.85637861e-03, -4.41956072e-04]],
#
#         [[-4.33047768e-03,  6.35588868e-03],
#          [-3.00543034e-04,  1.20795257e-02],
#          [ 1.71131771e-02,  1.49615286e-02],
#          ...,
#          [ 1.32448496e-02, -5.13690989e-03],
#          [-1.36897638e-02,  3.36464006e-03],
#          [ 5.66754676e-03,  2.48845201e-03]],
#
#         [[-4.14542519e-05,  2.47704750e-03],
#          [ 1.97252911e-03,  2.01938860e-03],
#          [-1.29256854e-02, -1.23228133e-03],
#          ...,
#          [ 1.36225935e-04, -1.08958520e-02],
#          [ 1.27928983e-03,  2.70231813e-03],
#          [-9.60989099e-04,  9.26267880e-04]],
#
#         ...,
#
#         [[-1.06960841e-04,  1.46880664e-03],
#          [-1.04797317e-03,  6.33276475e-04],
#          [ 1.91761553e-02,  1.16308201e-02],
#          ...,
#          [-1.08447550e-02, -6.66657696e-03],
#          [-3.33750364e-03,  3.80416727e-03],
#          [-2.58930004e-03, -3.49426130e-03]],
#
#         [[-8.77886731e-03, -5.68693643e-03],
#          [-1.99718345e-02,  2.80686910e-03],
#          [ 2.47826036e-02,  1.44943101e-02],
#          ...,
#          [-1.88772772e-02, -1.37328161e-02],
#          [ 2.87372665e-03,  1.88265592e-02],
#          [-1.40148755e-02, -4.23732866e-03]],
#
#         [[-1.23004727e-02, -3.47546767e-03],
#          [-1.84228737e-02,  3.28457053e-03],
#          [ 3.17206606e-03,  2.73630302e-03],
#          ...,
#          [ 1.34935207e-03, -2.85290927e-03],
#          [-6.33492228e-03,  4.32708208e-03],
#          [-3.90029582e-03, -2.61352491e-03]]]], dtype=float32), 'label': np.int64(1)}

# %%
activities_df = fall_grouped
activities_df['Timestamp'] = pd.to_datetime(activities_df['Timestamp'])

print(" type of", activities_df['Timestamp'])
# Out:
#  type of 1     2018-07-04 12:04:20.238369
# 2     2018-07-04 12:04:20.738369
# 3     2018-07-04 12:04:21.238369
# 4     2018-07-04 12:04:21.738369
# 5     2018-07-04 12:04:22.238369
#                  ...
# 628   2018-07-12 11:59:55.648720
# 629   2018-07-12 12:00:10.275836
# 630   2018-07-12 12:00:10.775836
# 631   2018-07-12 12:00:11.275836
# 632   2018-07-12 12:00:11.775836
# Name: Timestamp, Length: 632, dtype: datetime64[ns]

# %% [markdown]
# # Labeling the windows
#
# These functions are also from KTP, but adjusted to work with with my data

# %%
import os
import numpy as np
import pandas as pd
from concurrent.futures import ThreadPoolExecutor

def update_file(file_path: str, label: int):
    try:
        data = np.load(file_path, allow_pickle=True)
        # Update its 'label' key; otherwise, wrap it.
        if isinstance(data, dict):
            data['label'] = np.int64(label)
        else:
            data = {"array": data, "label": np.int64(label)}
        np.save(file_path, data)
        print(f"Updated {file_path} with label: {label}")
    except Exception as e:
        print(f"Error processing file {file_path}: {e}")

# Base directory where the processed optical flow npy files are stored.
processed_base_dir = f"/content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_{version_number}/videos/processed-npy-files"
df = activities_df

# Iterate through each activity folder in the processed directory.
for folder_name in os.listdir(processed_base_dir):
    folder_path = os.path.join(processed_base_dir, folder_name)
    if not os.path.isdir(folder_path):
        continue

    print(f"Processing folder: {folder_name}")

    # Filter the dataframe rows that correspond to this folder.
    folder_df = df[df['full_path'].str.contains(folder_name)]
    if folder_df.empty:
        print(f"No matching dataframe rows for folder {folder_name}.")
        continue

    # Sort the dataframe by Timestamp
    folder_df = folder_df.sort_values("Timestamp").reset_index(drop=True)

    # List the npy files and sort them.
    npy_files = sorted([f for f in os.listdir(folder_path) if f.endswith(".npy")])

    if len(npy_files) != len(folder_df):
        print(f"Warning: In folder {folder_name}, number of npy files ({len(npy_files)}) does not match number of dataframe rows ({len(folder_df)}).")

    # Update files concurrently using ThreadPoolExecutor.
    with ThreadPoolExecutor() as executor:
        # Zip the sorted npy files with the corresponding Tag from the dataframe.
        for npy_file, label in zip(npy_files, folder_df['Tag']):
            file_path = os.path.join(folder_path, npy_file)
            executor.submit(update_file, file_path, label)
# Out:
# Processing folder: Subject1Activity1Trial1Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity1Trial1Camera1/window_001.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity1Trial1Camera1/window_002.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity1Trial1Camera1/window_000.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity1Trial1Camera1/window_004.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity1Trial1Camera1/window_005.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity1Trial1Camera1/window_003.npy with label: 1
# Processing folder: Subject1Activity1Trial3Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity1Trial3Camera1/window_002.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity1Trial3Camera1/window_001.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity1Trial3Camera1/window_003.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity1Trial3Camera1/window_000.npy with label: 1
# Processing folder: Subject1Activity2Trial1Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity2Trial1Camera1/window_000.npy with label: 2
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity2Trial1Camera1/window_001.npy with label: 2
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity2Trial1Camera1/window_003.npy with label: 2
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity2Trial1Camera1/window_002.npy with label: 2
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity2Trial1Camera1/window_004.npy with label: 2
# Processing folder: Subject1Activity3Trial1Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity3Trial1Camera1/window_001.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity3Trial1Camera1/window_005.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity3Trial1Camera1/window_002.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity3Trial1Camera1/window_000.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity3Trial1Camera1/window_003.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity3Trial1Camera1/window_004.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity3Trial1Camera1/window_006.npy with label: 3
# Processing folder: Subject1Activity3Trial2Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity3Trial2Camera1/window_000.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity3Trial2Camera1/window_005.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity3Trial2Camera1/window_001.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity3Trial2Camera1/window_002.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity3Trial2Camera1/window_003.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity3Trial2Camera1/window_004.npy with label: 3
# Processing folder: Subject1Activity3Trial3Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity3Trial3Camera1/window_002.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity3Trial3Camera1/window_003.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity3Trial3Camera1/window_005.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity3Trial3Camera1/window_000.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity3Trial3Camera1/window_004.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity3Trial3Camera1/window_001.npy with label: 3
# Processing folder: Subject1Activity4Trial1Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity4Trial1Camera1/window_003.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity4Trial1Camera1/window_001.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity4Trial1Camera1/window_002.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity4Trial1Camera1/window_000.npy with label: 4
# Processing folder: Subject1Activity5Trial1Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity5Trial1Camera1/window_002.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity5Trial1Camera1/window_001.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity5Trial1Camera1/window_005.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity5Trial1Camera1/window_004.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity5Trial1Camera1/window_003.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity5Trial1Camera1/window_000.npy with label: 5
# Processing folder: Subject1Activity5Trial2Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity5Trial2Camera1/window_000.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity5Trial2Camera1/window_001.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity5Trial2Camera1/window_002.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity5Trial2Camera1/window_003.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity5Trial2Camera1/window_004.npy with label: 5
# Processing folder: Subject1Activity5Trial3Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity5Trial3Camera1/window_001.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity5Trial3Camera1/window_000.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity5Trial3Camera1/window_002.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity5Trial3Camera1/window_005.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity5Trial3Camera1/window_003.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject1Activity5Trial3Camera1/window_004.npy with label: 5
# Processing folder: Subject3Activity1Trial1Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity1Trial1Camera1/window_000.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity1Trial1Camera1/window_002.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity1Trial1Camera1/window_001.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity1Trial1Camera1/window_003.npy with label: 1
# Processing folder: Subject3Activity1Trial2Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity1Trial2Camera1/window_003.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity1Trial2Camera1/window_002.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity1Trial2Camera1/window_000.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity1Trial2Camera1/window_005.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity1Trial2Camera1/window_004.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity1Trial2Camera1/window_001.npy with label: 1
# Processing folder: Subject3Activity1Trial3Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity1Trial3Camera1/window_001.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity1Trial3Camera1/window_000.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity1Trial3Camera1/window_003.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity1Trial3Camera1/window_002.npy with label: 1
# Processing folder: Subject3Activity2Trial1Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity2Trial1Camera1/window_000.npy with label: 2
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity2Trial1Camera1/window_005.npy with label: 2
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity2Trial1Camera1/window_001.npy with label: 2
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity2Trial1Camera1/window_002.npy with label: 2
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity2Trial1Camera1/window_004.npy with label: 2
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity2Trial1Camera1/window_003.npy with label: 2
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity2Trial1Camera1/window_006.npy with label: 2
# Processing folder: Subject3Activity3Trial2Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity3Trial2Camera1/window_001.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity3Trial2Camera1/window_000.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity3Trial2Camera1/window_002.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity3Trial2Camera1/window_004.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity3Trial2Camera1/window_003.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity3Trial2Camera1/window_005.npy with label: 3
# Processing folder: Subject3Activity3Trial3Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity3Trial3Camera1/window_003.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity3Trial3Camera1/window_000.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity3Trial3Camera1/window_002.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity3Trial3Camera1/window_004.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity3Trial3Camera1/window_001.npy with label: 3
# Processing folder: Subject3Activity4Trial1Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity4Trial1Camera1/window_001.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity4Trial1Camera1/window_003.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity4Trial1Camera1/window_000.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity4Trial1Camera1/window_002.npy with label: 4
# Processing folder: Subject3Activity4Trial2Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity4Trial2Camera1/window_001.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity4Trial2Camera1/window_002.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity4Trial2Camera1/window_003.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity4Trial2Camera1/window_000.npy with label: 4
# Processing folder: Subject3Activity4Trial3Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity4Trial3Camera1/window_002.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity4Trial3Camera1/window_001.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity4Trial3Camera1/window_000.npy with label: 4
# Processing folder: Subject3Activity5Trial1Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity5Trial1Camera1/window_002.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity5Trial1Camera1/window_000.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity5Trial1Camera1/window_003.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity5Trial1Camera1/window_001.npy with label: 5
# Processing folder: Subject3Activity5Trial2Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity5Trial2Camera1/window_000.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity5Trial2Camera1/window_001.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity5Trial2Camera1/window_002.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject3Activity5Trial2Camera1/window_003.npy with label: 5
# Processing folder: Subject5Activity1Trial1Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject5Activity1Trial1Camera1/window_002.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject5Activity1Trial1Camera1/window_001.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject5Activity1Trial1Camera1/window_000.npy with label: 1
# Processing folder: Subject5Activity1Trial2Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject5Activity1Trial2Camera1/window_002.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject5Activity1Trial2Camera1/window_001.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject5Activity1Trial2Camera1/window_000.npy with label: 1
# Processing folder: Subject5Activity3Trial1Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject5Activity3Trial1Camera1/window_001.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject5Activity3Trial1Camera1/window_002.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject5Activity3Trial1Camera1/window_000.npy with label: 3
# Processing folder: Subject5Activity4Trial1Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject5Activity4Trial1Camera1/window_002.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject5Activity4Trial1Camera1/window_000.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject5Activity4Trial1Camera1/window_001.npy with label: 4
# Processing folder: Subject5Activity4Trial3Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject5Activity4Trial3Camera1/window_002.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject5Activity4Trial3Camera1/window_000.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject5Activity4Trial3Camera1/window_001.npy with label: 4
# Processing folder: Subject5Activity5Trial1Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject5Activity5Trial1Camera1/window_000.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject5Activity5Trial1Camera1/window_002.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject5Activity5Trial1Camera1/window_001.npy with label: 5
# Processing folder: Subject6Activity1Trial1Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject6Activity1Trial1Camera1/window_000.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject6Activity1Trial1Camera1/window_002.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject6Activity1Trial1Camera1/window_001.npy with label: 1
# Processing folder: Subject6Activity1Trial3Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject6Activity1Trial3Camera1/window_000.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject6Activity1Trial3Camera1/window_002.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject6Activity1Trial3Camera1/window_001.npy with label: 1
# Processing folder: Subject6Activity2Trial2Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject6Activity2Trial2Camera1/window_001.npy with label: 2
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject6Activity2Trial2Camera1/window_000.npy with label: 2
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject6Activity2Trial2Camera1/window_002.npy with label: 2
# Processing folder: Subject6Activity2Trial3Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject6Activity2Trial3Camera1/window_002.npy with label: 2
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject6Activity2Trial3Camera1/window_000.npy with label: 2
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject6Activity2Trial3Camera1/window_001.npy with label: 2
# Processing folder: Subject6Activity3Trial1Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject6Activity3Trial1Camera1/window_002.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject6Activity3Trial1Camera1/window_001.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject6Activity3Trial1Camera1/window_000.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject6Activity3Trial1Camera1/window_003.npy with label: 3
# Processing folder: Subject6Activity3Trial2Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject6Activity3Trial2Camera1/window_001.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject6Activity3Trial2Camera1/window_000.npy with label: 3
# Processing folder: Subject6Activity5Trial2Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject6Activity5Trial2Camera1/window_001.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject6Activity5Trial2Camera1/window_002.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject6Activity5Trial2Camera1/window_000.npy with label: 5
# Processing folder: Subject7Activity1Trial1Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject7Activity1Trial1Camera1/window_001.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject7Activity1Trial1Camera1/window_000.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject7Activity1Trial1Camera1/window_002.npy with label: 1
# Processing folder: Subject7Activity1Trial3Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject7Activity1Trial3Camera1/window_001.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject7Activity1Trial3Camera1/window_002.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject7Activity1Trial3Camera1/window_000.npy with label: 1
# Processing folder: Subject7Activity3Trial1Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject7Activity3Trial1Camera1/window_001.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject7Activity3Trial1Camera1/window_000.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject7Activity3Trial1Camera1/window_002.npy with label: 3
# Processing folder: Subject7Activity3Trial2Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject7Activity3Trial2Camera1/window_001.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject7Activity3Trial2Camera1/window_002.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject7Activity3Trial2Camera1/window_000.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject7Activity3Trial2Camera1/window_003.npy with label: 3
# Processing folder: Subject7Activity3Trial3Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject7Activity3Trial3Camera1/window_001.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject7Activity3Trial3Camera1/window_002.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject7Activity3Trial3Camera1/window_000.npy with label: 3
# Processing folder: Subject7Activity4Trial1Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject7Activity4Trial1Camera1/window_002.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject7Activity4Trial1Camera1/window_001.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject7Activity4Trial1Camera1/window_000.npy with label: 4
# Processing folder: Subject7Activity4Trial2Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject7Activity4Trial2Camera1/window_000.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject7Activity4Trial2Camera1/window_001.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject7Activity4Trial2Camera1/window_003.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject7Activity4Trial2Camera1/window_002.npy with label: 4
# Processing folder: Subject7Activity4Trial3Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject7Activity4Trial3Camera1/window_001.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject7Activity4Trial3Camera1/window_002.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject7Activity4Trial3Camera1/window_000.npy with label: 4
# Processing folder: Subject7Activity5Trial1Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject7Activity5Trial1Camera1/window_004.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject7Activity5Trial1Camera1/window_000.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject7Activity5Trial1Camera1/window_002.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject7Activity5Trial1Camera1/window_003.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject7Activity5Trial1Camera1/window_001.npy with label: 5
# Processing folder: Subject7Activity5Trial3Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject7Activity5Trial3Camera1/window_000.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject7Activity5Trial3Camera1/window_003.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject7Activity5Trial3Camera1/window_001.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject7Activity5Trial3Camera1/window_002.npy with label: 5
# Processing folder: Subject8Activity2Trial1Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity2Trial1Camera1/window_000.npy with label: 2
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity2Trial1Camera1/window_003.npy with label: 2
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity2Trial1Camera1/window_004.npy with label: 2
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity2Trial1Camera1/window_002.npy with label: 2
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity2Trial1Camera1/window_001.npy with label: 2
# Processing folder: Subject8Activity2Trial2Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity2Trial2Camera1/window_000.npy with label: 2
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity2Trial2Camera1/window_001.npy with label: 2
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity2Trial2Camera1/window_003.npy with label: 2
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity2Trial2Camera1/window_002.npy with label: 2
# Processing folder: Subject8Activity2Trial3Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity2Trial3Camera1/window_000.npy with label: 2
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity2Trial3Camera1/window_002.npy with label: 2
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity2Trial3Camera1/window_001.npy with label: 2
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity2Trial3Camera1/window_003.npy with label: 2
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity2Trial3Camera1/window_004.npy with label: 2
# Processing folder: Subject8Activity3Trial1Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity3Trial1Camera1/window_001.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity3Trial1Camera1/window_000.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity3Trial1Camera1/window_003.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity3Trial1Camera1/window_005.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity3Trial1Camera1/window_004.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity3Trial1Camera1/window_002.npy with label: 3
# Processing folder: Subject8Activity4Trial1Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity4Trial1Camera1/window_001.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity4Trial1Camera1/window_002.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity4Trial1Camera1/window_003.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity4Trial1Camera1/window_000.npy with label: 4
# Processing folder: Subject8Activity4Trial2Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity4Trial2Camera1/window_001.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity4Trial2Camera1/window_004.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity4Trial2Camera1/window_000.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity4Trial2Camera1/window_002.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity4Trial2Camera1/window_003.npy with label: 4
# Processing folder: Subject8Activity4Trial3Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity4Trial3Camera1/window_000.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity4Trial3Camera1/window_002.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity4Trial3Camera1/window_001.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity4Trial3Camera1/window_003.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity4Trial3Camera1/window_004.npy with label: 4
# Processing folder: Subject8Activity5Trial1Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity5Trial1Camera1/window_001.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity5Trial1Camera1/window_000.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity5Trial1Camera1/window_002.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity5Trial1Camera1/window_004.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity5Trial1Camera1/window_005.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity5Trial1Camera1/window_003.npy with label: 5
# Processing folder: Subject8Activity5Trial2Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity5Trial2Camera1/window_003.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity5Trial2Camera1/window_001.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity5Trial2Camera1/window_000.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity5Trial2Camera1/window_004.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity5Trial2Camera1/window_002.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity5Trial2Camera1/window_005.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity5Trial2Camera1/window_006.npy with label: 5
# Processing folder: Subject8Activity5Trial3Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity5Trial3Camera1/window_001.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity5Trial3Camera1/window_004.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity5Trial3Camera1/window_003.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity5Trial3Camera1/window_005.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity5Trial3Camera1/window_000.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject8Activity5Trial3Camera1/window_002.npy with label: 5
# Processing folder: Subject9Activity1Trial1Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject9Activity1Trial1Camera1/window_001.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject9Activity1Trial1Camera1/window_000.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject9Activity1Trial1Camera1/window_002.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject9Activity1Trial1Camera1/window_003.npy with label: 1
# Processing folder: Subject9Activity2Trial1Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject9Activity2Trial1Camera1/window_001.npy with label: 2
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject9Activity2Trial1Camera1/window_002.npy with label: 2
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject9Activity2Trial1Camera1/window_000.npy with label: 2
# Processing folder: Subject9Activity2Trial2Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject9Activity2Trial2Camera1/window_001.npy with label: 2
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject9Activity2Trial2Camera1/window_002.npy with label: 2
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject9Activity2Trial2Camera1/window_000.npy with label: 2
# Processing folder: Subject9Activity3Trial1Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject9Activity3Trial1Camera1/window_002.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject9Activity3Trial1Camera1/window_000.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject9Activity3Trial1Camera1/window_003.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject9Activity3Trial1Camera1/window_001.npy with label: 3
# Processing folder: Subject9Activity3Trial2Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject9Activity3Trial2Camera1/window_001.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject9Activity3Trial2Camera1/window_003.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject9Activity3Trial2Camera1/window_002.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject9Activity3Trial2Camera1/window_000.npy with label: 3
# Processing folder: Subject9Activity3Trial3Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject9Activity3Trial3Camera1/window_003.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject9Activity3Trial3Camera1/window_000.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject9Activity3Trial3Camera1/window_004.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject9Activity3Trial3Camera1/window_001.npy with label: 3
# ...
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject16Activity2Trial3Camera1/window_000.npy with label: 2
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject16Activity2Trial3Camera1/window_001.npy with label: 2
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject16Activity2Trial3Camera1/window_002.npy with label: 2
# Processing folder: Subject16Activity3Trial1Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject16Activity3Trial1Camera1/window_002.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject16Activity3Trial1Camera1/window_000.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject16Activity3Trial1Camera1/window_001.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject16Activity3Trial1Camera1/window_003.npy with label: 3
# Processing folder: Subject16Activity3Trial3Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject16Activity3Trial3Camera1/window_001.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject16Activity3Trial3Camera1/window_000.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject16Activity3Trial3Camera1/window_003.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject16Activity3Trial3Camera1/window_002.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject16Activity3Trial3Camera1/window_004.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject16Activity3Trial3Camera1/window_005.npy with label: 3
# Processing folder: Subject16Activity4Trial1Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject16Activity4Trial1Camera1/window_001.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject16Activity4Trial1Camera1/window_003.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject16Activity4Trial1Camera1/window_002.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject16Activity4Trial1Camera1/window_000.npy with label: 4
# Processing folder: Subject16Activity4Trial2Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject16Activity4Trial2Camera1/window_001.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject16Activity4Trial2Camera1/window_000.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject16Activity4Trial2Camera1/window_002.npy with label: 4
# Processing folder: Subject16Activity5Trial1Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject16Activity5Trial1Camera1/window_001.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject16Activity5Trial1Camera1/window_003.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject16Activity5Trial1Camera1/window_004.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject16Activity5Trial1Camera1/window_000.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject16Activity5Trial1Camera1/window_002.npy with label: 5
# Processing folder: Subject16Activity5Trial2Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject16Activity5Trial2Camera1/window_004.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject16Activity5Trial2Camera1/window_001.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject16Activity5Trial2Camera1/window_003.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject16Activity5Trial2Camera1/window_002.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject16Activity5Trial2Camera1/window_000.npy with label: 5
# Processing folder: Subject17Activity1Trial1Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity1Trial1Camera1/window_000.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity1Trial1Camera1/window_002.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity1Trial1Camera1/window_003.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity1Trial1Camera1/window_001.npy with label: 1
# Processing folder: Subject17Activity1Trial2Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity1Trial2Camera1/window_001.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity1Trial2Camera1/window_003.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity1Trial2Camera1/window_002.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity1Trial2Camera1/window_000.npy with label: 1
# Processing folder: Subject17Activity1Trial3Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity1Trial3Camera1/window_000.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity1Trial3Camera1/window_002.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity1Trial3Camera1/window_001.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity1Trial3Camera1/window_004.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity1Trial3Camera1/window_003.npy with label: 1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity1Trial3Camera1/window_005.npy with label: 1
# Processing folder: Subject17Activity2Trial1Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity2Trial1Camera1/window_003.npy with label: 2
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity2Trial1Camera1/window_002.npy with label: 2
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity2Trial1Camera1/window_000.npy with label: 2
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity2Trial1Camera1/window_001.npy with label: 2
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity2Trial1Camera1/window_004.npy with label: 2
# Processing folder: Subject17Activity2Trial3Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity2Trial3Camera1/window_001.npy with label: 2
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity2Trial3Camera1/window_002.npy with label: 2
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity2Trial3Camera1/window_003.npy with label: 2
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity2Trial3Camera1/window_004.npy with label: 2
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity2Trial3Camera1/window_000.npy with label: 2
# Processing folder: Subject17Activity3Trial1Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity3Trial1Camera1/window_002.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity3Trial1Camera1/window_003.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity3Trial1Camera1/window_001.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity3Trial1Camera1/window_000.npy with label: 3
# Processing folder: Subject17Activity3Trial2Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity3Trial2Camera1/window_000.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity3Trial2Camera1/window_001.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity3Trial2Camera1/window_004.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity3Trial2Camera1/window_002.npy with label: 3
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity3Trial2Camera1/window_003.npy with label: 3
# Processing folder: Subject17Activity4Trial1Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity4Trial1Camera1/window_001.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity4Trial1Camera1/window_002.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity4Trial1Camera1/window_000.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity4Trial1Camera1/window_003.npy with label: 4
# Processing folder: Subject17Activity4Trial3Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity4Trial3Camera1/window_001.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity4Trial3Camera1/window_003.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity4Trial3Camera1/window_002.npy with label: 4
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity4Trial3Camera1/window_000.npy with label: 4
# Processing folder: Subject17Activity5Trial1Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity5Trial1Camera1/window_000.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity5Trial1Camera1/window_002.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity5Trial1Camera1/window_003.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity5Trial1Camera1/window_001.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity5Trial1Camera1/window_004.npy with label: 5
# Processing folder: Subject17Activity5Trial2Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity5Trial2Camera1/window_004.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity5Trial2Camera1/window_000.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity5Trial2Camera1/window_002.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity5Trial2Camera1/window_003.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity5Trial2Camera1/window_001.npy with label: 5
# Processing folder: Subject17Activity5Trial3Camera1
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity5Trial3Camera1/window_000.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity5Trial3Camera1/window_001.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity5Trial3Camera1/window_002.npy with label: 5
# Updated /content/drive/MyDrive/Herts - BSc /3rd Year/FYP/trained_models/vae_model_v10.10/videos/processed-npy-files/Subject17Activity5Trial3Camera1/window_003.npy with label: 5
